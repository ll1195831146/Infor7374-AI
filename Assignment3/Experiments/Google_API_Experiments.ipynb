# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="creds.json"

# %%
# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# Instantiates a client
client = language.LanguageServiceClient()

# The text to analyze
text = u'Hello, world!'
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

print('Text: {}'.format(text))
print('Sentiment: {}, {}'.format(sentiment.score, sentiment.magnitude))
# Out:
# Text: Hello, world!
# Sentiment: 0.30000001192092896, 0.30000001192092896

# %%
def print_result(annotations):
    score = annotations.document_sentiment.score
    magnitude = annotations.document_sentiment.magnitude

    for index, sentence in enumerate(annotations.sentences):
        sentence_sentiment = sentence.sentiment.score
        print('Sentence {} has a sentiment score of {}'.format(
            index, sentence_sentiment))

    print('Overall Sentiment: score of {} with magnitude of {}'.format(
        score, magnitude))
    return 0

# %%
def analyze(movie_review_filename):
    """Run a sentiment analysis request on text within a passed filename."""
    client = language.LanguageServiceClient()

    with open(movie_review_filename, 'r') as review_file:
        # Instantiates a plain text document.
        content = review_file.read()

    document = types.Document(
        content=content,
        type=enums.Document.Type.PLAIN_TEXT)
    annotations = client.analyze_sentiment(document=document)

    # Print the results
    print_result(annotations)

# %%
analyze("Dataset_for_GoogleAPI.csv")
# Out:
# Sentence 0 has a sentiment score of 0.0
# Sentence 1 has a sentiment score of 0.0
# Sentence 2 has a sentiment score of 0.0
# Sentence 3 has a sentiment score of 0.0
# Sentence 4 has a sentiment score of 0.699999988079071
# Sentence 5 has a sentiment score of 0.0
# Sentence 6 has a sentiment score of 0.0
# Sentence 7 has a sentiment score of 0.0
# Sentence 8 has a sentiment score of 0.20000000298023224
# Sentence 9 has a sentiment score of 0.800000011920929
# Sentence 10 has a sentiment score of 0.0
# Sentence 11 has a sentiment score of 0.0
# Sentence 12 has a sentiment score of 0.0
# Sentence 13 has a sentiment score of 0.30000001192092896
# Sentence 14 has a sentiment score of 0.0
# Sentence 15 has a sentiment score of 0.0
# Sentence 16 has a sentiment score of 0.30000001192092896
# Sentence 17 has a sentiment score of 0.10000000149011612
# Sentence 18 has a sentiment score of 0.0
# Sentence 19 has a sentiment score of 0.4000000059604645
# Sentence 20 has a sentiment score of 0.0
# Sentence 21 has a sentiment score of 0.0
# Sentence 22 has a sentiment score of 0.0
# Sentence 23 has a sentiment score of 0.4000000059604645
# Sentence 24 has a sentiment score of 0.0
# Sentence 25 has a sentiment score of 0.699999988079071
# Sentence 26 has a sentiment score of 0.0
# Sentence 27 has a sentiment score of 0.20000000298023224
# Sentence 28 has a sentiment score of 0.0
# Sentence 29 has a sentiment score of -0.800000011920929
# Sentence 30 has a sentiment score of -0.6000000238418579
# Sentence 31 has a sentiment score of 0.0
# Sentence 32 has a sentiment score of 0.699999988079071
# Sentence 33 has a sentiment score of 0.0
# Sentence 34 has a sentiment score of 0.4000000059604645
# Sentence 35 has a sentiment score of 0.10000000149011612
# Sentence 36 has a sentiment score of 0.5
# Sentence 37 has a sentiment score of 0.800000011920929
# Sentence 38 has a sentiment score of -0.10000000149011612
# Sentence 39 has a sentiment score of 0.30000001192092896
# Sentence 40 has a sentiment score of 0.0
# Sentence 41 has a sentiment score of 0.0
# Sentence 42 has a sentiment score of 0.0
# Sentence 43 has a sentiment score of 0.5
# Sentence 44 has a sentiment score of 0.8999999761581421
# Sentence 45 has a sentiment score of 0.699999988079071
# Sentence 46 has a sentiment score of 0.6000000238418579
# Sentence 47 has a sentiment score of 0.10000000149011612
# Sentence 48 has a sentiment score of 0.5
# Sentence 49 has a sentiment score of 0.800000011920929
# Sentence 50 has a sentiment score of 0.800000011920929
# Sentence 51 has a sentiment score of 0.20000000298023224
# Sentence 52 has a sentiment score of 0.8999999761581421
# Sentence 53 has a sentiment score of 0.699999988079071
# Sentence 54 has a sentiment score of 0.8999999761581421
# Sentence 55 has a sentiment score of -0.10000000149011612
# Sentence 56 has a sentiment score of 0.699999988079071
# Sentence 57 has a sentiment score of 0.10000000149011612
# Sentence 58 has a sentiment score of 0.30000001192092896
# Sentence 59 has a sentiment score of 0.0
# Sentence 60 has a sentiment score of 0.0
# Sentence 61 has a sentiment score of -0.30000001192092896
# Sentence 62 has a sentiment score of 0.4000000059604645
# Sentence 63 has a sentiment score of 0.699999988079071
# Sentence 64 has a sentiment score of 0.4000000059604645
# Sentence 65 has a sentiment score of 0.0
# Sentence 66 has a sentiment score of -0.20000000298023224
# Sentence 67 has a sentiment score of 0.699999988079071
# Sentence 68 has a sentiment score of 0.800000011920929
# Sentence 69 has a sentiment score of 0.6000000238418579
# Sentence 70 has a sentiment score of 0.20000000298023224
# Sentence 71 has a sentiment score of 0.0
# Sentence 72 has a sentiment score of -0.4000000059604645
# Sentence 73 has a sentiment score of 0.800000011920929
# Sentence 74 has a sentiment score of 0.0
# Sentence 75 has a sentiment score of -0.5
# Sentence 76 has a sentiment score of -0.20000000298023224
# Sentence 77 has a sentiment score of 0.10000000149011612
# Sentence 78 has a sentiment score of 0.10000000149011612
# Sentence 79 has a sentiment score of -0.30000001192092896
# Sentence 80 has a sentiment score of 0.8999999761581421
# Sentence 81 has a sentiment score of 0.8999999761581421
# Sentence 82 has a sentiment score of 0.8999999761581421
# Sentence 83 has a sentiment score of 0.10000000149011612
# Sentence 84 has a sentiment score of 0.0
# Sentence 85 has a sentiment score of 0.4000000059604645
# Sentence 86 has a sentiment score of 0.800000011920929
# Sentence 87 has a sentiment score of 0.6000000238418579
# Sentence 88 has a sentiment score of 0.800000011920929
# Sentence 89 has a sentiment score of 0.5
# Sentence 90 has a sentiment score of 0.0
# Sentence 91 has a sentiment score of -0.30000001192092896
# Sentence 92 has a sentiment score of 0.30000001192092896
# Sentence 93 has a sentiment score of -0.5
# Sentence 94 has a sentiment score of -0.20000000298023224
# Sentence 95 has a sentiment score of -0.10000000149011612
# Sentence 96 has a sentiment score of 0.0
# Sentence 97 has a sentiment score of 0.5
# Sentence 98 has a sentiment score of 0.0
# Sentence 99 has a sentiment score of 0.0
# Sentence 100 has a sentiment score of 0.6000000238418579
# Sentence 101 has a sentiment score of 0.10000000149011612
# Sentence 102 has a sentiment score of 0.0
# Sentence 103 has a sentiment score of 0.800000011920929
# Sentence 104 has a sentiment score of 0.10000000149011612
# Sentence 105 has a sentiment score of 0.30000001192092896
# Sentence 106 has a sentiment score of 0.20000000298023224
# Sentence 107 has a sentiment score of 0.30000001192092896
# Sentence 108 has a sentiment score of 0.0
# Sentence 109 has a sentiment score of 0.10000000149011612
# Sentence 110 has a sentiment score of 0.0
# Sentence 111 has a sentiment score of -0.699999988079071
# Sentence 112 has a sentiment score of -0.10000000149011612
# Sentence 113 has a sentiment score of 0.0
# Sentence 114 has a sentiment score of -0.6000000238418579
# Sentence 115 has a sentiment score of -0.20000000298023224
# Sentence 116 has a sentiment score of -0.5
# Sentence 117 has a sentiment score of -0.10000000149011612
# Sentence 118 has a sentiment score of -0.30000001192092896
# Sentence 119 has a sentiment score of -0.5
# Sentence 120 has a sentiment score of 0.5
# Sentence 121 has a sentiment score of -0.6000000238418579
# Sentence 122 has a sentiment score of -0.800000011920929
# Sentence 123 has a sentiment score of -0.699999988079071
# Sentence 124 has a sentiment score of -0.800000011920929
# Sentence 125 has a sentiment score of 0.0
# Sentence 126 has a sentiment score of 0.0
# Sentence 127 has a sentiment score of -0.5
# Sentence 128 has a sentiment score of -0.6000000238418579
# Sentence 129 has a sentiment score of 0.800000011920929
# Sentence 130 has a sentiment score of 0.30000001192092896
# Sentence 131 has a sentiment score of 0.30000001192092896
# Sentence 132 has a sentiment score of 0.4000000059604645
# Sentence 133 has a sentiment score of 0.20000000298023224
# Sentence 134 has a sentiment score of 0.4000000059604645
# Sentence 135 has a sentiment score of 0.5
# Sentence 136 has a sentiment score of 0.0
# Sentence 137 has a sentiment score of -0.20000000298023224
# Sentence 138 has a sentiment score of 0.20000000298023224
# Sentence 139 has a sentiment score of 0.8999999761581421
# Sentence 140 has a sentiment score of 0.800000011920929
# Sentence 141 has a sentiment score of 0.10000000149011612
# Sentence 142 has a sentiment score of 0.0
# Sentence 143 has a sentiment score of 0.0
# Sentence 144 has a sentiment score of 0.0
# Sentence 145 has a sentiment score of 0.20000000298023224
# Sentence 146 has a sentiment score of -0.5
# Sentence 147 has a sentiment score of 0.0
# Sentence 148 has a sentiment score of 0.0
# Sentence 149 has a sentiment score of 0.4000000059604645
# Sentence 150 has a sentiment score of 0.0
# Sentence 151 has a sentiment score of 0.0
# Sentence 152 has a sentiment score of -0.30000001192092896
# Sentence 153 has a sentiment score of 0.0
# Sentence 154 has a sentiment score of -0.20000000298023224
# Sentence 155 has a sentiment score of 0.0
# Sentence 156 has a sentiment score of 0.0
# Sentence 157 has a sentiment score of 0.0
# Sentence 158 has a sentiment score of 0.5
# Sentence 159 has a sentiment score of 0.699999988079071
# Sentence 160 has a sentiment score of 0.20000000298023224
# Sentence 161 has a sentiment score of 0.5
# Sentence 162 has a sentiment score of 0.6000000238418579
# Sentence 163 has a sentiment score of 0.0
# Sentence 164 has a sentiment score of 0.0
# Sentence 165 has a sentiment score of 0.10000000149011612
# Sentence 166 has a sentiment score of 0.0
# Sentence 167 has a sentiment score of -0.10000000149011612
# Sentence 168 has a sentiment score of 0.4000000059604645
# Sentence 169 has a sentiment score of 0.0
# Sentence 170 has a sentiment score of 0.0
# Sentence 171 has a sentiment score of 0.10000000149011612
# Sentence 172 has a sentiment score of 0.20000000298023224
# Sentence 173 has a sentiment score of 0.30000001192092896
# Sentence 174 has a sentiment score of -0.800000011920929
# Sentence 175 has a sentiment score of 0.5
# Sentence 176 has a sentiment score of 0.8999999761581421
# Sentence 177 has a sentiment score of 0.30000001192092896
# Sentence 178 has a sentiment score of -0.10000000149011612
# Sentence 179 has a sentiment score of 0.0
# Sentence 180 has a sentiment score of 0.8999999761581421
# Sentence 181 has a sentiment score of 0.0
# Sentence 182 has a sentiment score of 0.0
# Sentence 183 has a sentiment score of 0.0
# Sentence 184 has a sentiment score of -0.10000000149011612
# Sentence 185 has a sentiment score of 0.0
# Sentence 186 has a sentiment score of 0.0
# Sentence 187 has a sentiment score of -0.699999988079071
# Sentence 188 has a sentiment score of 0.0
# Sentence 189 has a sentiment score of 0.0
# Sentence 190 has a sentiment score of 0.6000000238418579
# Sentence 191 has a sentiment score of 0.6000000238418579
# Sentence 192 has a sentiment score of 0.800000011920929
# Sentence 193 has a sentiment score of -0.4000000059604645
# Sentence 194 has a sentiment score of 0.30000001192092896
# Sentence 195 has a sentiment score of 0.0
# Sentence 196 has a sentiment score of -0.20000000298023224
# Sentence 197 has a sentiment score of -0.20000000298023224
# Sentence 198 has a sentiment score of 0.800000011920929
# Sentence 199 has a sentiment score of 0.20000000298023224
# Sentence 200 has a sentiment score of -0.6000000238418579
# Sentence 201 has a sentiment score of -0.699999988079071
# Sentence 202 has a sentiment score of -0.20000000298023224
# Sentence 203 has a sentiment score of -0.10000000149011612
# Sentence 204 has a sentiment score of -0.10000000149011612
# Sentence 205 has a sentiment score of 0.6000000238418579
# Sentence 206 has a sentiment score of 0.10000000149011612
# Sentence 207 has a sentiment score of 0.0
# Sentence 208 has a sentiment score of 0.10000000149011612
# Sentence 209 has a sentiment score of 0.5
# Sentence 210 has a sentiment score of 0.0
# Sentence 211 has a sentiment score of 0.0
# Sentence 212 has a sentiment score of -0.4000000059604645
# Sentence 213 has a sentiment score of 0.0
# Sentence 214 has a sentiment score of 0.800000011920929
# Sentence 215 has a sentiment score of 0.0
# Sentence 216 has a sentiment score of 0.4000000059604645
# Sentence 217 has a sentiment score of 0.699999988079071
# Sentence 218 has a sentiment score of 0.5
# Sentence 219 has a sentiment score of 0.6000000238418579
# Sentence 220 has a sentiment score of 0.0
# Sentence 221 has a sentiment score of 0.0
# Sentence 222 has a sentiment score of -0.30000001192092896
# Sentence 223 has a sentiment score of 0.0
# Sentence 224 has a sentiment score of 0.0
# Sentence 225 has a sentiment score of -0.20000000298023224
# Sentence 226 has a sentiment score of -0.5
# Sentence 227 has a sentiment score of 0.0
# Sentence 228 has a sentiment score of 0.4000000059604645
# Sentence 229 has a sentiment score of 0.699999988079071
# Sentence 230 has a sentiment score of 0.0
# Sentence 231 has a sentiment score of 0.0
# Sentence 232 has a sentiment score of 0.30000001192092896
# Sentence 233 has a sentiment score of -0.20000000298023224
# Sentence 234 has a sentiment score of 0.0
# Sentence 235 has a sentiment score of 0.8999999761581421
# Sentence 236 has a sentiment score of 0.10000000149011612
# Sentence 237 has a sentiment score of -0.20000000298023224
# Sentence 238 has a sentiment score of 0.20000000298023224
# Sentence 239 has a sentiment score of 0.0
# Sentence 240 has a sentiment score of 0.0
# Sentence 241 has a sentiment score of 0.0
# Sentence 242 has a sentiment score of 0.0
# Sentence 243 has a sentiment score of -0.10000000149011612
# Sentence 244 has a sentiment score of 0.0
# Sentence 245 has a sentiment score of -0.10000000149011612
# Sentence 246 has a sentiment score of 0.0
# Sentence 247 has a sentiment score of 0.0
# Sentence 248 has a sentiment score of -0.10000000149011612
# Sentence 249 has a sentiment score of -0.30000001192092896
# Sentence 250 has a sentiment score of 0.0
# Sentence 251 has a sentiment score of -0.30000001192092896
# Sentence 252 has a sentiment score of 0.0
# Sentence 253 has a sentiment score of 0.4000000059604645
# Sentence 254 has a sentiment score of 0.5
# Sentence 255 has a sentiment score of 0.0
# Sentence 256 has a sentiment score of 0.4000000059604645
# Sentence 257 has a sentiment score of 0.0
# Sentence 258 has a sentiment score of -0.10000000149011612
# Sentence 259 has a sentiment score of 0.5
# Sentence 260 has a sentiment score of 0.10000000149011612
# Sentence 261 has a sentiment score of 0.800000011920929
# Sentence 262 has a sentiment score of 0.0
# Sentence 263 has a sentiment score of 0.0
# Sentence 264 has a sentiment score of 0.0
# Sentence 265 has a sentiment score of -0.30000001192092896
# Sentence 266 has a sentiment score of 0.30000001192092896
# Sentence 267 has a sentiment score of 0.0
# Sentence 268 has a sentiment score of 0.30000001192092896
# Sentence 269 has a sentiment score of 0.0
# Sentence 270 has a sentiment score of -0.20000000298023224
# Sentence 271 has a sentiment score of 0.20000000298023224
# Sentence 272 has a sentiment score of 0.0
# Sentence 273 has a sentiment score of 0.0
# Sentence 274 has a sentiment score of 0.0
# Sentence 275 has a sentiment score of 0.0
# Sentence 276 has a sentiment score of -0.20000000298023224
# Sentence 277 has a sentiment score of 0.30000001192092896
# Sentence 278 has a sentiment score of 0.0
# Sentence 279 has a sentiment score of 0.20000000298023224
# Sentence 280 has a sentiment score of 0.0
# Sentence 281 has a sentiment score of 0.0
# Sentence 282 has a sentiment score of -0.10000000149011612
# Sentence 283 has a sentiment score of 0.0
# Sentence 284 has a sentiment score of 0.0
# Sentence 285 has a sentiment score of 0.0
# Sentence 286 has a sentiment score of -0.5
# Sentence 287 has a sentiment score of 0.0
# Sentence 288 has a sentiment score of 0.0
# Sentence 289 has a sentiment score of 0.0
# Sentence 290 has a sentiment score of 0.0
# Sentence 291 has a sentiment score of 0.699999988079071
# Sentence 292 has a sentiment score of 0.699999988079071
# Sentence 293 has a sentiment score of 0.6000000238418579
# Sentence 294 has a sentiment score of 0.800000011920929
# Sentence 295 has a sentiment score of 0.10000000149011612
# Sentence 296 has a sentiment score of 0.30000001192092896
# Sentence 297 has a sentiment score of 0.30000001192092896
# Sentence 298 has a sentiment score of -0.10000000149011612
# Sentence 299 has a sentiment score of 0.0
# Sentence 300 has a sentiment score of 0.0
# Sentence 301 has a sentiment score of 0.30000001192092896
# Sentence 302 has a sentiment score of 0.0
# Sentence 303 has a sentiment score of 0.800000011920929
# Sentence 304 has a sentiment score of 0.0
# Sentence 305 has a sentiment score of 0.0
# Sentence 306 has a sentiment score of 0.0
# Sentence 307 has a sentiment score of 0.20000000298023224
# Sentence 308 has a sentiment score of 0.0
# Sentence 309 has a sentiment score of 0.0
# Sentence 310 has a sentiment score of 0.0
# Sentence 311 has a sentiment score of 0.0
# Sentence 312 has a sentiment score of -0.30000001192092896
# Sentence 313 has a sentiment score of 0.5
# Sentence 314 has a sentiment score of 0.0
# Sentence 315 has a sentiment score of 0.0
# Sentence 316 has a sentiment score of 0.699999988079071
# Sentence 317 has a sentiment score of -0.20000000298023224
# Sentence 318 has a sentiment score of 0.0
# Sentence 319 has a sentiment score of 0.0
# Sentence 320 has a sentiment score of 0.0
# Sentence 321 has a sentiment score of 0.0
# Sentence 322 has a sentiment score of 0.10000000149011612
# Sentence 323 has a sentiment score of 0.10000000149011612
# Sentence 324 has a sentiment score of 0.20000000298023224
# Sentence 325 has a sentiment score of 0.20000000298023224
# Sentence 326 has a sentiment score of -0.6000000238418579
# Sentence 327 has a sentiment score of 0.0
# Sentence 328 has a sentiment score of -0.10000000149011612
# Sentence 329 has a sentiment score of 0.800000011920929
# Sentence 330 has a sentiment score of 0.0
# Sentence 331 has a sentiment score of 0.0
# Sentence 332 has a sentiment score of 0.0
# Sentence 333 has a sentiment score of 0.8999999761581421
# Sentence 334 has a sentiment score of 0.30000001192092896
# Sentence 335 has a sentiment score of 0.4000000059604645
# Sentence 336 has a sentiment score of 0.0
# Sentence 337 has a sentiment score of 0.800000011920929
# Sentence 338 has a sentiment score of 0.0
# Sentence 339 has a sentiment score of 0.0
# Sentence 340 has a sentiment score of 0.0
# Sentence 341 has a sentiment score of 0.0
# Sentence 342 has a sentiment score of 0.20000000298023224
# Sentence 343 has a sentiment score of 0.0
# Sentence 344 has a sentiment score of 0.6000000238418579
# Sentence 345 has a sentiment score of 0.0
# Sentence 346 has a sentiment score of 0.20000000298023224
# Sentence 347 has a sentiment score of 0.800000011920929
# Sentence 348 has a sentiment score of 0.0
# Sentence 349 has a sentiment score of 0.0
# Sentence 350 has a sentiment score of 0.10000000149011612
# Sentence 351 has a sentiment score of 0.10000000149011612
# Sentence 352 has a sentiment score of 0.4000000059604645
# Sentence 353 has a sentiment score of 0.800000011920929
# Sentence 354 has a sentiment score of 0.6000000238418579
# Sentence 355 has a sentiment score of 0.10000000149011612
# Sentence 356 has a sentiment score of 0.0
# Sentence 357 has a sentiment score of 0.0
# Sentence 358 has a sentiment score of 0.0
# Sentence 359 has a sentiment score of 0.0
# Sentence 360 has a sentiment score of 0.4000000059604645
# Sentence 361 has a sentiment score of 0.5
# Sentence 362 has a sentiment score of 0.0
# Sentence 363 has a sentiment score of 0.0
# Sentence 364 has a sentiment score of 0.10000000149011612
# Sentence 365 has a sentiment score of -0.10000000149011612
# Sentence 366 has a sentiment score of 0.20000000298023224
# Sentence 367 has a sentiment score of 0.699999988079071
# Sentence 368 has a sentiment score of 0.699999988079071
# Sentence 369 has a sentiment score of -0.10000000149011612
# Sentence 370 has a sentiment score of 0.10000000149011612
# Sentence 371 has a sentiment score of 0.10000000149011612
# Sentence 372 has a sentiment score of 0.6000000238418579
# Sentence 373 has a sentiment score of 0.0
# Sentence 374 has a sentiment score of 0.4000000059604645
# Sentence 375 has a sentiment score of 0.4000000059604645
# Sentence 376 has a sentiment score of 0.4000000059604645
# Sentence 377 has a sentiment score of -0.30000001192092896
# Sentence 378 has a sentiment score of 0.10000000149011612
# Sentence 379 has a sentiment score of 0.0
# Sentence 380 has a sentiment score of 0.0
# Sentence 381 has a sentiment score of 0.0
# Sentence 382 has a sentiment score of 0.0
# Sentence 383 has a sentiment score of 0.20000000298023224
# Sentence 384 has a sentiment score of 0.10000000149011612
# Sentence 385 has a sentiment score of 0.4000000059604645
# Sentence 386 has a sentiment score of 0.0
# Sentence 387 has a sentiment score of 0.699999988079071
# Sentence 388 has a sentiment score of 0.10000000149011612
# Sentence 389 has a sentiment score of 0.0
# Sentence 390 has a sentiment score of 0.10000000149011612
# Sentence 391 has a sentiment score of 0.0
# Sentence 392 has a sentiment score of 0.4000000059604645
# Sentence 393 has a sentiment score of 0.10000000149011612
# Sentence 394 has a sentiment score of 0.0
# Sentence 395 has a sentiment score of 0.6000000238418579
# Sentence 396 has a sentiment score of 0.10000000149011612
# Sentence 397 has a sentiment score of 0.0
# Sentence 398 has a sentiment score of -0.30000001192092896
# Sentence 399 has a sentiment score of -0.4000000059604645
# Sentence 400 has a sentiment score of 0.0
# Sentence 401 has a sentiment score of -0.4000000059604645
# Sentence 402 has a sentiment score of -0.4000000059604645
# Sentence 403 has a sentiment score of 0.10000000149011612
# Sentence 404 has a sentiment score of 0.6000000238418579
# Sentence 405 has a sentiment score of 0.4000000059604645
# Sentence 406 has a sentiment score of 0.800000011920929
# Sentence 407 has a sentiment score of 0.800000011920929
# Sentence 408 has a sentiment score of 0.20000000298023224
# Sentence 409 has a sentiment score of 0.800000011920929
# Sentence 410 has a sentiment score of 0.8999999761581421
# Sentence 411 has a sentiment score of 0.800000011920929
# Sentence 412 has a sentiment score of 0.699999988079071
# Sentence 413 has a sentiment score of 0.5
# Sentence 414 has a sentiment score of 0.10000000149011612
# Sentence 415 has a sentiment score of 0.0
# Sentence 416 has a sentiment score of -0.10000000149011612
# Sentence 417 has a sentiment score of -0.800000011920929
# Sentence 418 has a sentiment score of -0.20000000298023224
# Sentence 419 has a sentiment score of 0.800000011920929
# Sentence 420 has a sentiment score of 0.5
# Sentence 421 has a sentiment score of 0.6000000238418579
# Sentence 422 has a sentiment score of 0.0
# Sentence 423 has a sentiment score of 0.0
# Sentence 424 has a sentiment score of -0.10000000149011612
# Sentence 425 has a sentiment score of 0.0
# Sentence 426 has a sentiment score of 0.800000011920929
# Sentence 427 has a sentiment score of 0.0
# Sentence 428 has a sentiment score of 0.699999988079071
# Sentence 429 has a sentiment score of 0.0
# Sentence 430 has a sentiment score of 0.0
# Sentence 431 has a sentiment score of 0.0
# Sentence 432 has a sentiment score of 0.6000000238418579
# Sentence 433 has a sentiment score of 0.6000000238418579
# Sentence 434 has a sentiment score of 0.8999999761581421
# Sentence 435 has a sentiment score of 0.8999999761581421
# Sentence 436 has a sentiment score of 0.0
# Sentence 437 has a sentiment score of 0.6000000238418579
# Sentence 438 has a sentiment score of 0.8999999761581421
# Sentence 439 has a sentiment score of 0.20000000298023224
# Sentence 440 has a sentiment score of 0.10000000149011612
# Sentence 441 has a sentiment score of 0.0
# Sentence 442 has a sentiment score of 0.0
# Sentence 443 has a sentiment score of -0.10000000149011612
# Sentence 444 has a sentiment score of -0.6000000238418579
# Sentence 445 has a sentiment score of -0.699999988079071
# Sentence 446 has a sentiment score of -0.6000000238418579
# Sentence 447 has a sentiment score of 0.0
# Sentence 448 has a sentiment score of 0.4000000059604645
# Sentence 449 has a sentiment score of 0.8999999761581421
# Sentence 450 has a sentiment score of 0.6000000238418579
# Sentence 451 has a sentiment score of 0.6000000238418579
# Sentence 452 has a sentiment score of 0.0
# Sentence 453 has a sentiment score of 0.800000011920929
# Sentence 454 has a sentiment score of 0.0
# Sentence 455 has a sentiment score of 0.800000011920929
# Sentence 456 has a sentiment score of -0.800000011920929
# Sentence 457 has a sentiment score of 0.30000001192092896
# Sentence 458 has a sentiment score of 0.4000000059604645
# Sentence 459 has a sentiment score of 0.4000000059604645
# Sentence 460 has a sentiment score of 0.699999988079071
# Sentence 461 has a sentiment score of 0.20000000298023224
# Sentence 462 has a sentiment score of 0.0
# Sentence 463 has a sentiment score of 0.0
# Sentence 464 has a sentiment score of 0.20000000298023224
# Sentence 465 has a sentiment score of 0.0
# Sentence 466 has a sentiment score of 0.0
# Sentence 467 has a sentiment score of 0.4000000059604645
# Sentence 468 has a sentiment score of 0.800000011920929
# Sentence 469 has a sentiment score of 0.0
# Sentence 470 has a sentiment score of 0.0
# Sentence 471 has a sentiment score of -0.20000000298023224
# Sentence 472 has a sentiment score of 0.10000000149011612
# Sentence 473 has a sentiment score of -0.5
# Sentence 474 has a sentiment score of 0.20000000298023224
# Sentence 475 has a sentiment score of 0.4000000059604645
# Sentence 476 has a sentiment score of -0.30000001192092896
# Sentence 477 has a sentiment score of 0.0
# Sentence 478 has a sentiment score of 0.10000000149011612
# Sentence 479 has a sentiment score of 0.0
# Sentence 480 has a sentiment score of 0.10000000149011612
# Sentence 481 has a sentiment score of -0.30000001192092896
# Sentence 482 has a sentiment score of -0.10000000149011612
# Sentence 483 has a sentiment score of -0.10000000149011612
# Sentence 484 has a sentiment score of 0.800000011920929
# Sentence 485 has a sentiment score of 0.6000000238418579
# Sentence 486 has a sentiment score of 0.0
# Sentence 487 has a sentiment score of 0.10000000149011612
# Sentence 488 has a sentiment score of 0.30000001192092896
# Sentence 489 has a sentiment score of 0.0
# Sentence 490 has a sentiment score of 0.0
# Sentence 491 has a sentiment score of -0.10000000149011612
# Sentence 492 has a sentiment score of 0.0
# Sentence 493 has a sentiment score of 0.0
# Sentence 494 has a sentiment score of 0.30000001192092896
# Sentence 495 has a sentiment score of 0.0
# Sentence 496 has a sentiment score of 0.0
# Sentence 497 has a sentiment score of 0.0
# Sentence 498 has a sentiment score of 0.0
# Sentence 499 has a sentiment score of 0.0
# Sentence 500 has a sentiment score of 0.0
# Sentence 501 has a sentiment score of 0.0
# Sentence 502 has a sentiment score of -0.20000000298023224
# Sentence 503 has a sentiment score of 0.0
# Sentence 504 has a sentiment score of 0.0
# Sentence 505 has a sentiment score of 0.20000000298023224
# Sentence 506 has a sentiment score of 0.30000001192092896
# Sentence 507 has a sentiment score of 0.0
# Sentence 508 has a sentiment score of -0.20000000298023224
# Sentence 509 has a sentiment score of 0.0
# Sentence 510 has a sentiment score of 0.0
# Sentence 511 has a sentiment score of 0.0
# Sentence 512 has a sentiment score of 0.4000000059604645
# Sentence 513 has a sentiment score of 0.0
# Sentence 514 has a sentiment score of 0.30000001192092896
# Sentence 515 has a sentiment score of 0.0
# Sentence 516 has a sentiment score of -0.20000000298023224
# Sentence 517 has a sentiment score of 0.0
# Sentence 518 has a sentiment score of -0.10000000149011612
# Sentence 519 has a sentiment score of -0.30000001192092896
# Sentence 520 has a sentiment score of -0.4000000059604645
# Sentence 521 has a sentiment score of 0.0
# Sentence 522 has a sentiment score of 0.6000000238418579
# Sentence 523 has a sentiment score of 0.8999999761581421
# Sentence 524 has a sentiment score of 0.0
# Sentence 525 has a sentiment score of 0.10000000149011612
# Sentence 526 has a sentiment score of -0.10000000149011612
# Sentence 527 has a sentiment score of 0.8999999761581421
# Sentence 528 has a sentiment score of 0.0
# Sentence 529 has a sentiment score of 0.699999988079071
# Sentence 530 has a sentiment score of 0.0
# Sentence 531 has a sentiment score of 0.0
# Sentence 532 has a sentiment score of 0.0
# Sentence 533 has a sentiment score of 0.0
# Sentence 534 has a sentiment score of 0.10000000149011612
# Sentence 535 has a sentiment score of -0.30000001192092896
# Sentence 536 has a sentiment score of 0.0
# Sentence 537 has a sentiment score of 0.0
# Sentence 538 has a sentiment score of -0.30000001192092896
# Sentence 539 has a sentiment score of 0.10000000149011612
# Sentence 540 has a sentiment score of 0.4000000059604645
# Sentence 541 has a sentiment score of -0.30000001192092896
# Sentence 542 has a sentiment score of -0.5
# Sentence 543 has a sentiment score of 0.20000000298023224
# Sentence 544 has a sentiment score of -0.4000000059604645
# Sentence 545 has a sentiment score of 0.0
# Sentence 546 has a sentiment score of 0.0
# Sentence 547 has a sentiment score of -0.5
# Sentence 548 has a sentiment score of 0.0
# Sentence 549 has a sentiment score of 0.8999999761581421
# Sentence 550 has a sentiment score of 0.800000011920929
# Sentence 551 has a sentiment score of 0.0
# Sentence 552 has a sentiment score of 0.20000000298023224
# Sentence 553 has a sentiment score of 0.4000000059604645
# Sentence 554 has a sentiment score of 0.699999988079071
# Sentence 555 has a sentiment score of 0.30000001192092896
# Sentence 556 has a sentiment score of 0.4000000059604645
# Sentence 557 has a sentiment score of 0.0
# Sentence 558 has a sentiment score of 0.0
# Sentence 559 has a sentiment score of 0.0
# Sentence 560 has a sentiment score of 0.0
# Sentence 561 has a sentiment score of 0.0
# Sentence 562 has a sentiment score of 0.30000001192092896
# Sentence 563 has a sentiment score of -0.30000001192092896
# Sentence 564 has a sentiment score of 0.10000000149011612
# Sentence 565 has a sentiment score of 0.0
# Sentence 566 has a sentiment score of 0.0
# Sentence 567 has a sentiment score of 0.20000000298023224
# Sentence 568 has a sentiment score of 0.4000000059604645
# Sentence 569 has a sentiment score of 0.8999999761581421
# Sentence 570 has a sentiment score of -0.20000000298023224
# Sentence 571 has a sentiment score of 0.699999988079071
# Sentence 572 has a sentiment score of 0.800000011920929
# Sentence 573 has a sentiment score of -0.10000000149011612
# Sentence 574 has a sentiment score of 0.4000000059604645
# Sentence 575 has a sentiment score of 0.699999988079071
# Sentence 576 has a sentiment score of 0.800000011920929
# Sentence 577 has a sentiment score of 0.20000000298023224
# Sentence 578 has a sentiment score of 0.800000011920929
# Sentence 579 has a sentiment score of 0.10000000149011612
# Sentence 580 has a sentiment score of 0.8999999761581421
# Sentence 581 has a sentiment score of 0.0
# Sentence 582 has a sentiment score of 0.0
# Sentence 583 has a sentiment score of 0.699999988079071
# Sentence 584 has a sentiment score of 0.10000000149011612
# Sentence 585 has a sentiment score of 0.0
# Sentence 586 has a sentiment score of 0.10000000149011612
# Sentence 587 has a sentiment score of 0.10000000149011612
# Sentence 588 has a sentiment score of 0.0
# Sentence 589 has a sentiment score of 0.0
# Sentence 590 has a sentiment score of 0.0
# Sentence 591 has a sentiment score of -0.30000001192092896
# Sentence 592 has a sentiment score of 0.0
# Sentence 593 has a sentiment score of 0.0
# Sentence 594 has a sentiment score of 0.0
# Sentence 595 has a sentiment score of -0.20000000298023224
# Sentence 596 has a sentiment score of 0.0
# Sentence 597 has a sentiment score of 0.10000000149011612
# Sentence 598 has a sentiment score of 0.10000000149011612
# Sentence 599 has a sentiment score of 0.5
# Sentence 600 has a sentiment score of 0.0
# Sentence 601 has a sentiment score of 0.0
# Sentence 602 has a sentiment score of 0.0
# Sentence 603 has a sentiment score of 0.0
# Sentence 604 has a sentiment score of 0.10000000149011612
# Sentence 605 has a sentiment score of 0.10000000149011612
# Sentence 606 has a sentiment score of 0.5
# Sentence 607 has a sentiment score of 0.0
# Sentence 608 has a sentiment score of 0.0
# Sentence 609 has a sentiment score of 0.0
# Sentence 610 has a sentiment score of 0.0
# Sentence 611 has a sentiment score of 0.699999988079071
# Sentence 612 has a sentiment score of 0.30000001192092896
# Sentence 613 has a sentiment score of 0.0
# Sentence 614 has a sentiment score of 0.800000011920929
# Sentence 615 has a sentiment score of 0.0
# Sentence 616 has a sentiment score of 0.0
# Sentence 617 has a sentiment score of 0.8999999761581421
# Sentence 618 has a sentiment score of -0.10000000149011612
# Sentence 619 has a sentiment score of 0.20000000298023224
# Sentence 620 has a sentiment score of 0.10000000149011612
# Sentence 621 has a sentiment score of -0.5
# Sentence 622 has a sentiment score of 0.30000001192092896
# Sentence 623 has a sentiment score of 0.0
# Sentence 624 has a sentiment score of 0.4000000059604645
# Sentence 625 has a sentiment score of 0.10000000149011612
# Sentence 626 has a sentiment score of 0.30000001192092896
# Sentence 627 has a sentiment score of -0.20000000298023224
# Sentence 628 has a sentiment score of 0.10000000149011612
# Sentence 629 has a sentiment score of 0.0
# Sentence 630 has a sentiment score of 0.10000000149011612
# Sentence 631 has a sentiment score of -0.30000001192092896
# Sentence 632 has a sentiment score of 0.30000001192092896
# Sentence 633 has a sentiment score of -0.800000011920929
# Sentence 634 has a sentiment score of 0.10000000149011612
# Sentence 635 has a sentiment score of 0.10000000149011612
# Sentence 636 has a sentiment score of -0.20000000298023224
# Sentence 637 has a sentiment score of 0.0
# Sentence 638 has a sentiment score of 0.0
# Sentence 639 has a sentiment score of 0.699999988079071
# Sentence 640 has a sentiment score of 0.5
# Sentence 641 has a sentiment score of 0.800000011920929
# Sentence 642 has a sentiment score of 0.20000000298023224
# Sentence 643 has a sentiment score of -0.30000001192092896
# Sentence 644 has a sentiment score of 0.20000000298023224
# Sentence 645 has a sentiment score of 0.0
# Sentence 646 has a sentiment score of 0.8999999761581421
# Sentence 647 has a sentiment score of 0.4000000059604645
# Sentence 648 has a sentiment score of -0.20000000298023224
# Sentence 649 has a sentiment score of 0.0
# Sentence 650 has a sentiment score of 0.0
# Sentence 651 has a sentiment score of 0.4000000059604645
# Sentence 652 has a sentiment score of 0.5
# Sentence 653 has a sentiment score of -0.4000000059604645
# Sentence 654 has a sentiment score of 0.5
# Sentence 655 has a sentiment score of 0.0
# Sentence 656 has a sentiment score of 0.6000000238418579
# Sentence 657 has a sentiment score of 0.30000001192092896
# Sentence 658 has a sentiment score of 0.0
# Sentence 659 has a sentiment score of 0.5
# Sentence 660 has a sentiment score of 0.10000000149011612
# Sentence 661 has a sentiment score of -0.30000001192092896
# Sentence 662 has a sentiment score of 0.0
# Sentence 663 has a sentiment score of 0.699999988079071
# Sentence 664 has a sentiment score of 0.6000000238418579
# Sentence 665 has a sentiment score of 0.5
# Sentence 666 has a sentiment score of 0.6000000238418579
# Sentence 667 has a sentiment score of 0.10000000149011612
# Sentence 668 has a sentiment score of 0.10000000149011612
# Sentence 669 has a sentiment score of 0.8999999761581421
# Sentence 670 has a sentiment score of 0.5
# Sentence 671 has a sentiment score of 0.10000000149011612
# Sentence 672 has a sentiment score of 0.0
# Sentence 673 has a sentiment score of 0.0
# Sentence 674 has a sentiment score of -0.10000000149011612
# Sentence 675 has a sentiment score of 0.0
# Sentence 676 has a sentiment score of 0.0
# Sentence 677 has a sentiment score of 0.10000000149011612
# Sentence 678 has a sentiment score of 0.0
# Sentence 679 has a sentiment score of 0.0
# Sentence 680 has a sentiment score of 0.0
# Sentence 681 has a sentiment score of 0.0
# Sentence 682 has a sentiment score of 0.0
# Sentence 683 has a sentiment score of 0.10000000149011612
# Sentence 684 has a sentiment score of 0.6000000238418579
# Sentence 685 has a sentiment score of 0.699999988079071
# Sentence 686 has a sentiment score of -0.10000000149011612
# Sentence 687 has a sentiment score of 0.800000011920929
# Sentence 688 has a sentiment score of -0.30000001192092896
# Sentence 689 has a sentiment score of 0.30000001192092896
# Sentence 690 has a sentiment score of 0.800000011920929
# Sentence 691 has a sentiment score of 0.30000001192092896
# Sentence 692 has a sentiment score of 0.20000000298023224
# Sentence 693 has a sentiment score of 0.4000000059604645
# Sentence 694 has a sentiment score of 0.10000000149011612
# Sentence 695 has a sentiment score of 0.10000000149011612
# Sentence 696 has a sentiment score of 0.5
# Sentence 697 has a sentiment score of 0.10000000149011612
# Sentence 698 has a sentiment score of 0.20000000298023224
# Sentence 699 has a sentiment score of 0.0
# Sentence 700 has a sentiment score of -0.10000000149011612
# Sentence 701 has a sentiment score of 0.699999988079071
# Sentence 702 has a sentiment score of 0.8999999761581421
# Sentence 703 has a sentiment score of -0.10000000149011612
# Sentence 704 has a sentiment score of 0.4000000059604645
# Sentence 705 has a sentiment score of 0.0
# Sentence 706 has a sentiment score of 0.20000000298023224
# Sentence 707 has a sentiment score of 0.5
# Sentence 708 has a sentiment score of 0.0
# Sentence 709 has a sentiment score of 0.20000000298023224
# Sentence 710 has a sentiment score of -0.30000001192092896
# Sentence 711 has a sentiment score of 0.0
# Sentence 712 has a sentiment score of -0.30000001192092896
# Sentence 713 has a sentiment score of 0.4000000059604645
# Sentence 714 has a sentiment score of 0.0
# Sentence 715 has a sentiment score of 0.0
# Sentence 716 has a sentiment score of 0.0
# Sentence 717 has a sentiment score of 0.0
# Sentence 718 has a sentiment score of 0.30000001192092896
# Sentence 719 has a sentiment score of 0.10000000149011612
# Sentence 720 has a sentiment score of 0.0
# Sentence 721 has a sentiment score of -0.10000000149011612
# Sentence 722 has a sentiment score of 0.0
# Sentence 723 has a sentiment score of -0.30000001192092896
# Sentence 724 has a sentiment score of -0.30000001192092896
# Sentence 725 has a sentiment score of 0.0
# Sentence 726 has a sentiment score of 0.5
# Sentence 727 has a sentiment score of 0.800000011920929
# Sentence 728 has a sentiment score of 0.20000000298023224
# Sentence 729 has a sentiment score of -0.10000000149011612
# Sentence 730 has a sentiment score of 0.20000000298023224
# Sentence 731 has a sentiment score of 0.20000000298023224
# Sentence 732 has a sentiment score of 0.20000000298023224
# Sentence 733 has a sentiment score of 0.0
# Sentence 734 has a sentiment score of 0.0
# Sentence 735 has a sentiment score of -0.10000000149011612
# Sentence 736 has a sentiment score of 0.699999988079071
# Sentence 737 has a sentiment score of -0.5
# Sentence 738 has a sentiment score of 0.0
# Sentence 739 has a sentiment score of 0.0
# Sentence 740 has a sentiment score of 0.0
# Sentence 741 has a sentiment score of 0.4000000059604645
# Sentence 742 has a sentiment score of -0.20000000298023224
# Sentence 743 has a sentiment score of 0.10000000149011612
# Sentence 744 has a sentiment score of 0.0
# Sentence 745 has a sentiment score of 0.10000000149011612
# Sentence 746 has a sentiment score of 0.0
# Sentence 747 has a sentiment score of 0.6000000238418579
# Sentence 748 has a sentiment score of -0.10000000149011612
# Sentence 749 has a sentiment score of 0.30000001192092896
# Sentence 750 has a sentiment score of -0.10000000149011612
# Sentence 751 has a sentiment score of 0.30000001192092896
# Sentence 752 has a sentiment score of 0.800000011920929
# Sentence 753 has a sentiment score of 0.5
# Sentence 754 has a sentiment score of 0.20000000298023224
# Sentence 755 has a sentiment score of 0.800000011920929
# Sentence 756 has a sentiment score of 0.800000011920929
# Sentence 757 has a sentiment score of 0.5
# Sentence 758 has a sentiment score of 0.8999999761581421
# Sentence 759 has a sentiment score of 0.4000000059604645
# Sentence 760 has a sentiment score of 0.0
# Sentence 761 has a sentiment score of 0.10000000149011612
# Sentence 762 has a sentiment score of 0.5
# Sentence 763 has a sentiment score of 0.4000000059604645
# Sentence 764 has a sentiment score of 0.0
# Sentence 765 has a sentiment score of 0.30000001192092896
# Sentence 766 has a sentiment score of 0.0
# Sentence 767 has a sentiment score of 0.4000000059604645
# Sentence 768 has a sentiment score of -0.10000000149011612
# Sentence 769 has a sentiment score of 0.0
# Sentence 770 has a sentiment score of 0.20000000298023224
# Sentence 771 has a sentiment score of 0.0
# Sentence 772 has a sentiment score of 0.0
# Sentence 773 has a sentiment score of -0.699999988079071
# Sentence 774 has a sentiment score of 0.0
# Sentence 775 has a sentiment score of 0.30000001192092896
# Sentence 776 has a sentiment score of 0.800000011920929
# Sentence 777 has a sentiment score of 0.0
# Sentence 778 has a sentiment score of -0.30000001192092896
# Sentence 779 has a sentiment score of 0.5
# Sentence 780 has a sentiment score of 0.30000001192092896
# Sentence 781 has a sentiment score of 0.0
# Sentence 782 has a sentiment score of 0.800000011920929
# Sentence 783 has a sentiment score of 0.699999988079071
# Sentence 784 has a sentiment score of 0.800000011920929
# Sentence 785 has a sentiment score of 0.4000000059604645
# Sentence 786 has a sentiment score of 0.0
# Sentence 787 has a sentiment score of 0.10000000149011612
# Sentence 788 has a sentiment score of 0.0
# Sentence 789 has a sentiment score of 0.20000000298023224
# Sentence 790 has a sentiment score of 0.0
# Sentence 791 has a sentiment score of 0.0
# Sentence 792 has a sentiment score of 0.4000000059604645
# Sentence 793 has a sentiment score of 0.10000000149011612
# Sentence 794 has a sentiment score of -0.10000000149011612
# Sentence 795 has a sentiment score of 0.0
# Sentence 796 has a sentiment score of 0.0
# Sentence 797 has a sentiment score of 0.0
# Sentence 798 has a sentiment score of 0.8999999761581421
# Sentence 799 has a sentiment score of -0.20000000298023224
# Sentence 800 has a sentiment score of 0.10000000149011612
# Sentence 801 has a sentiment score of 0.699999988079071
# Sentence 802 has a sentiment score of 0.699999988079071
# Sentence 803 has a sentiment score of -0.30000001192092896
# Sentence 804 has a sentiment score of 0.8999999761581421
# Sentence 805 has a sentiment score of 0.4000000059604645
# Sentence 806 has a sentiment score of 0.8999999761581421
# Sentence 807 has a sentiment score of 0.6000000238418579
# Sentence 808 has a sentiment score of 0.6000000238418579
# Sentence 809 has a sentiment score of 0.800000011920929
# Sentence 810 has a sentiment score of 0.5
# Sentence 811 has a sentiment score of 0.10000000149011612
# Sentence 812 has a sentiment score of 0.0
# Sentence 813 has a sentiment score of 0.0
# Sentence 814 has a sentiment score of 0.5
# Sentence 815 has a sentiment score of -0.30000001192092896
# Sentence 816 has a sentiment score of 0.6000000238418579
# Sentence 817 has a sentiment score of 0.8999999761581421
# Sentence 818 has a sentiment score of 0.30000001192092896
# Sentence 819 has a sentiment score of 0.10000000149011612
# Sentence 820 has a sentiment score of -0.699999988079071
# Sentence 821 has a sentiment score of 0.30000001192092896
# Sentence 822 has a sentiment score of 0.6000000238418579
# Sentence 823 has a sentiment score of 0.30000001192092896
# Sentence 824 has a sentiment score of 0.0
# Sentence 825 has a sentiment score of 0.30000001192092896
# Sentence 826 has a sentiment score of 0.30000001192092896
# Sentence 827 has a sentiment score of -0.4000000059604645
# Sentence 828 has a sentiment score of -0.10000000149011612
# Sentence 829 has a sentiment score of 0.0
# Sentence 830 has a sentiment score of 0.8999999761581421
# Sentence 831 has a sentiment score of 0.699999988079071
# Sentence 832 has a sentiment score of 0.699999988079071
# Sentence 833 has a sentiment score of 0.8999999761581421
# Sentence 834 has a sentiment score of 0.0
# Sentence 835 has a sentiment score of 0.10000000149011612
# Sentence 836 has a sentiment score of 0.8999999761581421
# Sentence 837 has a sentiment score of 0.4000000059604645
# Sentence 838 has a sentiment score of 0.699999988079071
# Sentence 839 has a sentiment score of 0.0
# Sentence 840 has a sentiment score of 0.0
# Sentence 841 has a sentiment score of 0.0
# Sentence 842 has a sentiment score of 0.0
# Sentence 843 has a sentiment score of 0.0
# Sentence 844 has a sentiment score of 0.0
# Sentence 845 has a sentiment score of 0.0
# Sentence 846 has a sentiment score of 0.0
# Sentence 847 has a sentiment score of 0.0
# Sentence 848 has a sentiment score of 0.0
# Sentence 849 has a sentiment score of 0.30000001192092896
# Sentence 850 has a sentiment score of 0.4000000059604645
# Sentence 851 has a sentiment score of 0.6000000238418579
# Sentence 852 has a sentiment score of 0.0
# Sentence 853 has a sentiment score of -0.10000000149011612
# Sentence 854 has a sentiment score of 0.10000000149011612
# Sentence 855 has a sentiment score of -0.10000000149011612
# Sentence 856 has a sentiment score of -0.30000001192092896
# Sentence 857 has a sentiment score of -0.10000000149011612
# Sentence 858 has a sentiment score of 0.699999988079071
# Sentence 859 has a sentiment score of 0.0
# Sentence 860 has a sentiment score of 0.10000000149011612
# Sentence 861 has a sentiment score of 0.699999988079071
# Sentence 862 has a sentiment score of 0.0
# Sentence 863 has a sentiment score of 0.0
# Sentence 864 has a sentiment score of -0.10000000149011612
# Sentence 865 has a sentiment score of 0.10000000149011612
# Sentence 866 has a sentiment score of 0.0
# Sentence 867 has a sentiment score of 0.0
# Sentence 868 has a sentiment score of 0.10000000149011612
# Sentence 869 has a sentiment score of 0.0
# Sentence 870 has a sentiment score of 0.30000001192092896
# Sentence 871 has a sentiment score of 0.30000001192092896
# Sentence 872 has a sentiment score of 0.0
# Sentence 873 has a sentiment score of 0.0
# Sentence 874 has a sentiment score of 0.20000000298023224
# Sentence 875 has a sentiment score of 0.0
# Sentence 876 has a sentiment score of 0.0
# Sentence 877 has a sentiment score of 0.0
# Sentence 878 has a sentiment score of -0.5
# Sentence 879 has a sentiment score of -0.20000000298023224
# Sentence 880 has a sentiment score of 0.10000000149011612
# Sentence 881 has a sentiment score of -0.699999988079071
# Sentence 882 has a sentiment score of 0.699999988079071
# Sentence 883 has a sentiment score of 0.5
# Sentence 884 has a sentiment score of 0.0
# Sentence 885 has a sentiment score of 0.6000000238418579
# Sentence 886 has a sentiment score of 0.0
# Sentence 887 has a sentiment score of 0.0
# Sentence 888 has a sentiment score of 0.699999988079071
# Sentence 889 has a sentiment score of 0.6000000238418579
# Sentence 890 has a sentiment score of 0.800000011920929
# Sentence 891 has a sentiment score of 0.10000000149011612
# Sentence 892 has a sentiment score of 0.0
# Sentence 893 has a sentiment score of 0.0
# Sentence 894 has a sentiment score of 0.6000000238418579
# Sentence 895 has a sentiment score of 0.0
# Sentence 896 has a sentiment score of 0.0
# Sentence 897 has a sentiment score of 0.0
# Sentence 898 has a sentiment score of 0.0
# Sentence 899 has a sentiment score of 0.0
# Sentence 900 has a sentiment score of 0.4000000059604645
# Sentence 901 has a sentiment score of 0.4000000059604645
# Sentence 902 has a sentiment score of 0.0
# Sentence 903 has a sentiment score of 0.0
# Sentence 904 has a sentiment score of -0.6000000238418579
# Sentence 905 has a sentiment score of 0.30000001192092896
# Sentence 906 has a sentiment score of -0.20000000298023224
# Sentence 907 has a sentiment score of 0.699999988079071
# Sentence 908 has a sentiment score of 0.0
# Sentence 909 has a sentiment score of 0.4000000059604645
# Sentence 910 has a sentiment score of 0.10000000149011612
# Sentence 911 has a sentiment score of 0.4000000059604645
# Sentence 912 has a sentiment score of 0.0
# Sentence 913 has a sentiment score of -0.10000000149011612
# Sentence 914 has a sentiment score of -0.6000000238418579
# Sentence 915 has a sentiment score of 0.20000000298023224
# Sentence 916 has a sentiment score of 0.5
# Sentence 917 has a sentiment score of 0.0
# Sentence 918 has a sentiment score of -0.10000000149011612
# Sentence 919 has a sentiment score of -0.20000000298023224
# Sentence 920 has a sentiment score of 0.4000000059604645
# Sentence 921 has a sentiment score of 0.4000000059604645
# Sentence 922 has a sentiment score of 0.30000001192092896
# Sentence 923 has a sentiment score of 0.6000000238418579
# Sentence 924 has a sentiment score of 0.10000000149011612
# Sentence 925 has a sentiment score of 0.0
# Sentence 926 has a sentiment score of 0.4000000059604645
# Sentence 927 has a sentiment score of 0.10000000149011612
# Sentence 928 has a sentiment score of 0.8999999761581421
# Sentence 929 has a sentiment score of 0.20000000298023224
# Sentence 930 has a sentiment score of 0.699999988079071
# Sentence 931 has a sentiment score of 0.0
# Sentence 932 has a sentiment score of 0.30000001192092896
# Sentence 933 has a sentiment score of 0.0
# Sentence 934 has a sentiment score of 0.10000000149011612
# Sentence 935 has a sentiment score of 0.0
# Sentence 936 has a sentiment score of 0.0
# Sentence 937 has a sentiment score of 0.20000000298023224
# Sentence 938 has a sentiment score of 0.0
# Sentence 939 has a sentiment score of 0.0
# Sentence 940 has a sentiment score of 0.0
# ...
# Sentence 4199 has a sentiment score of 0.8999999761581421
# Sentence 4200 has a sentiment score of 0.4000000059604645
# Sentence 4201 has a sentiment score of 0.10000000149011612
# Sentence 4202 has a sentiment score of 0.8999999761581421
# Sentence 4203 has a sentiment score of 0.0
# Sentence 4204 has a sentiment score of 0.10000000149011612
# Sentence 4205 has a sentiment score of 0.20000000298023224
# Sentence 4206 has a sentiment score of 0.0
# Sentence 4207 has a sentiment score of 0.0
# Sentence 4208 has a sentiment score of 0.699999988079071
# Sentence 4209 has a sentiment score of 0.0
# Sentence 4210 has a sentiment score of 0.10000000149011612
# Sentence 4211 has a sentiment score of 0.30000001192092896
# Sentence 4212 has a sentiment score of 0.0
# Sentence 4213 has a sentiment score of -0.5
# Sentence 4214 has a sentiment score of -0.5
# Sentence 4215 has a sentiment score of 0.30000001192092896
# Sentence 4216 has a sentiment score of 0.4000000059604645
# Sentence 4217 has a sentiment score of -0.20000000298023224
# Sentence 4218 has a sentiment score of 0.699999988079071
# Sentence 4219 has a sentiment score of 0.0
# Sentence 4220 has a sentiment score of 0.30000001192092896
# Sentence 4221 has a sentiment score of 0.10000000149011612
# Sentence 4222 has a sentiment score of 0.800000011920929
# Sentence 4223 has a sentiment score of 0.0
# Sentence 4224 has a sentiment score of 0.699999988079071
# Sentence 4225 has a sentiment score of 0.20000000298023224
# Sentence 4226 has a sentiment score of 0.4000000059604645
# Sentence 4227 has a sentiment score of -0.20000000298023224
# Sentence 4228 has a sentiment score of 0.0
# Sentence 4229 has a sentiment score of 0.800000011920929
# Sentence 4230 has a sentiment score of 0.10000000149011612
# Sentence 4231 has a sentiment score of -0.10000000149011612
# Sentence 4232 has a sentiment score of 0.20000000298023224
# Sentence 4233 has a sentiment score of 0.10000000149011612
# Sentence 4234 has a sentiment score of 0.0
# Sentence 4235 has a sentiment score of 0.0
# Sentence 4236 has a sentiment score of 0.0
# Sentence 4237 has a sentiment score of 0.0
# Sentence 4238 has a sentiment score of 0.800000011920929
# Sentence 4239 has a sentiment score of 0.20000000298023224
# Sentence 4240 has a sentiment score of 0.5
# Sentence 4241 has a sentiment score of 0.10000000149011612
# Sentence 4242 has a sentiment score of 0.0
# Sentence 4243 has a sentiment score of 0.0
# Sentence 4244 has a sentiment score of 0.20000000298023224
# Sentence 4245 has a sentiment score of 0.30000001192092896
# Sentence 4246 has a sentiment score of -0.30000001192092896
# Sentence 4247 has a sentiment score of 0.20000000298023224
# Sentence 4248 has a sentiment score of 0.20000000298023224
# Sentence 4249 has a sentiment score of -0.20000000298023224
# Sentence 4250 has a sentiment score of 0.699999988079071
# Sentence 4251 has a sentiment score of 0.0
# Sentence 4252 has a sentiment score of 0.4000000059604645
# Sentence 4253 has a sentiment score of 0.0
# Sentence 4254 has a sentiment score of 0.20000000298023224
# Sentence 4255 has a sentiment score of 0.0
# Sentence 4256 has a sentiment score of 0.20000000298023224
# Sentence 4257 has a sentiment score of 0.20000000298023224
# Sentence 4258 has a sentiment score of -0.10000000149011612
# Sentence 4259 has a sentiment score of 0.800000011920929
# Sentence 4260 has a sentiment score of 0.10000000149011612
# Sentence 4261 has a sentiment score of 0.0
# Sentence 4262 has a sentiment score of 0.0
# Sentence 4263 has a sentiment score of 0.30000001192092896
# Sentence 4264 has a sentiment score of 0.0
# Sentence 4265 has a sentiment score of 0.20000000298023224
# Sentence 4266 has a sentiment score of 0.10000000149011612
# Sentence 4267 has a sentiment score of 0.4000000059604645
# Sentence 4268 has a sentiment score of 0.0
# Sentence 4269 has a sentiment score of 0.699999988079071
# Sentence 4270 has a sentiment score of 0.5
# Sentence 4271 has a sentiment score of 0.0
# Sentence 4272 has a sentiment score of 0.0
# Sentence 4273 has a sentiment score of -0.20000000298023224
# Sentence 4274 has a sentiment score of -0.6000000238418579
# Sentence 4275 has a sentiment score of 0.6000000238418579
# Sentence 4276 has a sentiment score of 0.0
# Sentence 4277 has a sentiment score of 0.20000000298023224
# Sentence 4278 has a sentiment score of 0.20000000298023224
# Sentence 4279 has a sentiment score of 0.0
# Sentence 4280 has a sentiment score of 0.30000001192092896
# Sentence 4281 has a sentiment score of 0.6000000238418579
# Sentence 4282 has a sentiment score of 0.4000000059604645
# Sentence 4283 has a sentiment score of 0.5
# Sentence 4284 has a sentiment score of 0.699999988079071
# Sentence 4285 has a sentiment score of 0.0
# Sentence 4286 has a sentiment score of 0.0
# Sentence 4287 has a sentiment score of 0.0
# Sentence 4288 has a sentiment score of -0.30000001192092896
# Sentence 4289 has a sentiment score of 0.30000001192092896
# Sentence 4290 has a sentiment score of -0.10000000149011612
# Sentence 4291 has a sentiment score of -0.10000000149011612
# Sentence 4292 has a sentiment score of 0.0
# Sentence 4293 has a sentiment score of 0.0
# Sentence 4294 has a sentiment score of 0.800000011920929
# Sentence 4295 has a sentiment score of 0.0
# Sentence 4296 has a sentiment score of 0.10000000149011612
# Sentence 4297 has a sentiment score of -0.20000000298023224
# Sentence 4298 has a sentiment score of -0.4000000059604645
# Sentence 4299 has a sentiment score of 0.10000000149011612
# Sentence 4300 has a sentiment score of 0.20000000298023224
# Sentence 4301 has a sentiment score of 0.699999988079071
# Sentence 4302 has a sentiment score of 0.5
# Sentence 4303 has a sentiment score of 0.0
# Sentence 4304 has a sentiment score of 0.699999988079071
# Sentence 4305 has a sentiment score of -0.4000000059604645
# Sentence 4306 has a sentiment score of -0.8999999761581421
# Sentence 4307 has a sentiment score of -0.4000000059604645
# Sentence 4308 has a sentiment score of 0.800000011920929
# Sentence 4309 has a sentiment score of 0.4000000059604645
# Sentence 4310 has a sentiment score of 0.699999988079071
# Sentence 4311 has a sentiment score of 0.699999988079071
# Sentence 4312 has a sentiment score of -0.6000000238418579
# Sentence 4313 has a sentiment score of 0.0
# Sentence 4314 has a sentiment score of -0.10000000149011612
# Sentence 4315 has a sentiment score of 0.6000000238418579
# Sentence 4316 has a sentiment score of -0.10000000149011612
# Sentence 4317 has a sentiment score of 0.0
# Sentence 4318 has a sentiment score of 0.0
# Sentence 4319 has a sentiment score of 0.20000000298023224
# Sentence 4320 has a sentiment score of 0.0
# Sentence 4321 has a sentiment score of 0.0
# Sentence 4322 has a sentiment score of 0.0
# Sentence 4323 has a sentiment score of 0.0
# Sentence 4324 has a sentiment score of 0.0
# Sentence 4325 has a sentiment score of -0.10000000149011612
# Sentence 4326 has a sentiment score of -0.10000000149011612
# Sentence 4327 has a sentiment score of -0.800000011920929
# Sentence 4328 has a sentiment score of -0.5
# Sentence 4329 has a sentiment score of 0.30000001192092896
# Sentence 4330 has a sentiment score of 0.6000000238418579
# Sentence 4331 has a sentiment score of 0.0
# Sentence 4332 has a sentiment score of 0.10000000149011612
# Sentence 4333 has a sentiment score of 0.20000000298023224
# Sentence 4334 has a sentiment score of 0.20000000298023224
# Sentence 4335 has a sentiment score of -0.5
# Sentence 4336 has a sentiment score of 0.20000000298023224
# Sentence 4337 has a sentiment score of 0.5
# Sentence 4338 has a sentiment score of 0.0
# Sentence 4339 has a sentiment score of 0.0
# Sentence 4340 has a sentiment score of 0.5
# Sentence 4341 has a sentiment score of 0.0
# Sentence 4342 has a sentiment score of 0.6000000238418579
# Sentence 4343 has a sentiment score of 0.20000000298023224
# Sentence 4344 has a sentiment score of 0.10000000149011612
# Sentence 4345 has a sentiment score of 0.20000000298023224
# Sentence 4346 has a sentiment score of 0.0
# Sentence 4347 has a sentiment score of 0.10000000149011612
# Sentence 4348 has a sentiment score of 0.0
# Sentence 4349 has a sentiment score of 0.10000000149011612
# Sentence 4350 has a sentiment score of -0.20000000298023224
# Sentence 4351 has a sentiment score of 0.0
# Sentence 4352 has a sentiment score of 0.0
# Sentence 4353 has a sentiment score of 0.4000000059604645
# Sentence 4354 has a sentiment score of 0.699999988079071
# Sentence 4355 has a sentiment score of 0.699999988079071
# Sentence 4356 has a sentiment score of 0.0
# Sentence 4357 has a sentiment score of 0.0
# Sentence 4358 has a sentiment score of -0.10000000149011612
# Sentence 4359 has a sentiment score of -0.699999988079071
# Sentence 4360 has a sentiment score of 0.0
# Sentence 4361 has a sentiment score of 0.0
# Sentence 4362 has a sentiment score of 0.0
# Sentence 4363 has a sentiment score of -0.4000000059604645
# Sentence 4364 has a sentiment score of 0.0
# Sentence 4365 has a sentiment score of 0.10000000149011612
# Sentence 4366 has a sentiment score of 0.0
# Sentence 4367 has a sentiment score of 0.0
# Sentence 4368 has a sentiment score of -0.30000001192092896
# Sentence 4369 has a sentiment score of 0.4000000059604645
# Sentence 4370 has a sentiment score of 0.0
# Sentence 4371 has a sentiment score of -0.30000001192092896
# Sentence 4372 has a sentiment score of -0.699999988079071
# Sentence 4373 has a sentiment score of 0.0
# Sentence 4374 has a sentiment score of 0.0
# Sentence 4375 has a sentiment score of 0.0
# Sentence 4376 has a sentiment score of 0.10000000149011612
# Sentence 4377 has a sentiment score of -0.6000000238418579
# Sentence 4378 has a sentiment score of 0.4000000059604645
# Sentence 4379 has a sentiment score of 0.20000000298023224
# Sentence 4380 has a sentiment score of 0.0
# Sentence 4381 has a sentiment score of 0.5
# Sentence 4382 has a sentiment score of -0.5
# Sentence 4383 has a sentiment score of 0.4000000059604645
# Sentence 4384 has a sentiment score of 0.8999999761581421
# Sentence 4385 has a sentiment score of 0.699999988079071
# Sentence 4386 has a sentiment score of -0.10000000149011612
# Sentence 4387 has a sentiment score of 0.0
# Sentence 4388 has a sentiment score of 0.0
# Sentence 4389 has a sentiment score of -0.4000000059604645
# Sentence 4390 has a sentiment score of 0.0
# Sentence 4391 has a sentiment score of 0.10000000149011612
# Sentence 4392 has a sentiment score of -0.10000000149011612
# Sentence 4393 has a sentiment score of 0.0
# Sentence 4394 has a sentiment score of 0.0
# Sentence 4395 has a sentiment score of 0.0
# Sentence 4396 has a sentiment score of -0.699999988079071
# Sentence 4397 has a sentiment score of 0.800000011920929
# Sentence 4398 has a sentiment score of 0.0
# Sentence 4399 has a sentiment score of 0.4000000059604645
# Sentence 4400 has a sentiment score of 0.8999999761581421
# Sentence 4401 has a sentiment score of 0.0
# Sentence 4402 has a sentiment score of 0.30000001192092896
# Sentence 4403 has a sentiment score of 0.0
# Sentence 4404 has a sentiment score of 0.800000011920929
# Sentence 4405 has a sentiment score of 0.0
# Sentence 4406 has a sentiment score of 0.30000001192092896
# Sentence 4407 has a sentiment score of 0.5
# Sentence 4408 has a sentiment score of 0.6000000238418579
# Sentence 4409 has a sentiment score of 0.4000000059604645
# Sentence 4410 has a sentiment score of -0.10000000149011612
# Sentence 4411 has a sentiment score of 0.699999988079071
# Sentence 4412 has a sentiment score of 0.800000011920929
# Sentence 4413 has a sentiment score of 0.0
# Sentence 4414 has a sentiment score of 0.0
# Sentence 4415 has a sentiment score of 0.0
# Sentence 4416 has a sentiment score of 0.30000001192092896
# Sentence 4417 has a sentiment score of -0.10000000149011612
# Sentence 4418 has a sentiment score of -0.10000000149011612
# Sentence 4419 has a sentiment score of 0.10000000149011612
# Sentence 4420 has a sentiment score of 0.4000000059604645
# Sentence 4421 has a sentiment score of -0.4000000059604645
# Sentence 4422 has a sentiment score of 0.20000000298023224
# Sentence 4423 has a sentiment score of 0.6000000238418579
# Sentence 4424 has a sentiment score of 0.5
# Sentence 4425 has a sentiment score of 0.0
# Sentence 4426 has a sentiment score of 0.800000011920929
# Sentence 4427 has a sentiment score of -0.10000000149011612
# Sentence 4428 has a sentiment score of -0.30000001192092896
# Sentence 4429 has a sentiment score of 0.20000000298023224
# Sentence 4430 has a sentiment score of 0.6000000238418579
# Sentence 4431 has a sentiment score of 0.699999988079071
# Sentence 4432 has a sentiment score of 0.0
# Sentence 4433 has a sentiment score of 0.0
# Sentence 4434 has a sentiment score of -0.20000000298023224
# Sentence 4435 has a sentiment score of 0.20000000298023224
# Sentence 4436 has a sentiment score of -0.800000011920929
# Sentence 4437 has a sentiment score of 0.10000000149011612
# Sentence 4438 has a sentiment score of 0.0
# Sentence 4439 has a sentiment score of 0.5
# Sentence 4440 has a sentiment score of 0.0
# Sentence 4441 has a sentiment score of 0.0
# Sentence 4442 has a sentiment score of 0.0
# Sentence 4443 has a sentiment score of 0.0
# Sentence 4444 has a sentiment score of 0.0
# Sentence 4445 has a sentiment score of 0.10000000149011612
# Sentence 4446 has a sentiment score of 0.0
# Sentence 4447 has a sentiment score of 0.0
# Sentence 4448 has a sentiment score of -0.5
# Sentence 4449 has a sentiment score of 0.0
# Sentence 4450 has a sentiment score of 0.0
# Sentence 4451 has a sentiment score of 0.699999988079071
# Sentence 4452 has a sentiment score of 0.699999988079071
# Sentence 4453 has a sentiment score of 0.0
# Sentence 4454 has a sentiment score of 0.0
# Sentence 4455 has a sentiment score of 0.4000000059604645
# Sentence 4456 has a sentiment score of 0.30000001192092896
# Sentence 4457 has a sentiment score of 0.10000000149011612
# Sentence 4458 has a sentiment score of -0.4000000059604645
# Sentence 4459 has a sentiment score of 0.6000000238418579
# Sentence 4460 has a sentiment score of 0.10000000149011612
# Sentence 4461 has a sentiment score of 0.0
# Sentence 4462 has a sentiment score of 0.5
# Sentence 4463 has a sentiment score of 0.0
# Sentence 4464 has a sentiment score of 0.5
# Sentence 4465 has a sentiment score of 0.20000000298023224
# Sentence 4466 has a sentiment score of -0.30000001192092896
# Sentence 4467 has a sentiment score of 0.0
# Sentence 4468 has a sentiment score of 0.0
# Sentence 4469 has a sentiment score of 0.0
# Sentence 4470 has a sentiment score of 0.800000011920929
# Sentence 4471 has a sentiment score of 0.0
# Sentence 4472 has a sentiment score of 0.800000011920929
# Sentence 4473 has a sentiment score of 0.4000000059604645
# Sentence 4474 has a sentiment score of 0.10000000149011612
# Sentence 4475 has a sentiment score of -0.10000000149011612
# Sentence 4476 has a sentiment score of 0.0
# Sentence 4477 has a sentiment score of -0.20000000298023224
# Sentence 4478 has a sentiment score of 0.0
# Sentence 4479 has a sentiment score of 0.0
# Sentence 4480 has a sentiment score of -0.4000000059604645
# Sentence 4481 has a sentiment score of 0.20000000298023224
# Sentence 4482 has a sentiment score of -0.20000000298023224
# Sentence 4483 has a sentiment score of 0.30000001192092896
# Sentence 4484 has a sentiment score of 0.4000000059604645
# Sentence 4485 has a sentiment score of 0.0
# Sentence 4486 has a sentiment score of 0.4000000059604645
# Sentence 4487 has a sentiment score of 0.0
# Sentence 4488 has a sentiment score of 0.0
# Sentence 4489 has a sentiment score of 0.0
# Sentence 4490 has a sentiment score of 0.10000000149011612
# Sentence 4491 has a sentiment score of 0.4000000059604645
# Sentence 4492 has a sentiment score of 0.30000001192092896
# Sentence 4493 has a sentiment score of 0.20000000298023224
# Sentence 4494 has a sentiment score of -0.20000000298023224
# Sentence 4495 has a sentiment score of 0.0
# Sentence 4496 has a sentiment score of 0.30000001192092896
# Sentence 4497 has a sentiment score of 0.10000000149011612
# Sentence 4498 has a sentiment score of -0.30000001192092896
# Sentence 4499 has a sentiment score of 0.0
# Sentence 4500 has a sentiment score of 0.0
# Sentence 4501 has a sentiment score of 0.5
# Sentence 4502 has a sentiment score of 0.0
# Overall Sentiment: score of 0.10000000149011612 with magnitude of 1357.199951171875

# %%
analyze("Complete.json")
# Out:
# Sentence 0 has a sentiment score of -0.4000000059604645
# Sentence 1 has a sentiment score of -0.4000000059604645
# Sentence 2 has a sentiment score of -0.10000000149011612
# Sentence 3 has a sentiment score of -0.4000000059604645
# Sentence 4 has a sentiment score of -0.4000000059604645
# Sentence 5 has a sentiment score of -0.4000000059604645
# Sentence 6 has a sentiment score of -0.30000001192092896
# Sentence 7 has a sentiment score of -0.30000001192092896
# Sentence 8 has a sentiment score of -0.5
# Sentence 9 has a sentiment score of -0.30000001192092896
# Sentence 10 has a sentiment score of -0.30000001192092896
# Sentence 11 has a sentiment score of -0.10000000149011612
# Sentence 12 has a sentiment score of -0.10000000149011612
# Sentence 13 has a sentiment score of -0.4000000059604645
# Sentence 14 has a sentiment score of -0.20000000298023224
# Sentence 15 has a sentiment score of -0.4000000059604645
# Sentence 16 has a sentiment score of -0.5
# Sentence 17 has a sentiment score of -0.20000000298023224
# Sentence 18 has a sentiment score of -0.30000001192092896
# Sentence 19 has a sentiment score of -0.20000000298023224
# Sentence 20 has a sentiment score of -0.20000000298023224
# Sentence 21 has a sentiment score of -0.30000001192092896
# Sentence 22 has a sentiment score of -0.30000001192092896
# Sentence 23 has a sentiment score of -0.4000000059604645
# Sentence 24 has a sentiment score of -0.30000001192092896
# Sentence 25 has a sentiment score of -0.4000000059604645
# Sentence 26 has a sentiment score of -0.30000001192092896
# Sentence 27 has a sentiment score of -0.30000001192092896
# Sentence 28 has a sentiment score of -0.699999988079071
# Sentence 29 has a sentiment score of -0.800000011920929
# Sentence 30 has a sentiment score of -0.699999988079071
# Sentence 31 has a sentiment score of -0.699999988079071
# Sentence 32 has a sentiment score of -0.800000011920929
# Sentence 33 has a sentiment score of -0.699999988079071
# Sentence 34 has a sentiment score of -0.800000011920929
# Sentence 35 has a sentiment score of -0.20000000298023224
# Sentence 36 has a sentiment score of -0.5
# Sentence 37 has a sentiment score of -0.4000000059604645
# Sentence 38 has a sentiment score of -0.4000000059604645
# Sentence 39 has a sentiment score of -0.5
# Sentence 40 has a sentiment score of -0.4000000059604645
# Sentence 41 has a sentiment score of -0.4000000059604645
# Sentence 42 has a sentiment score of 0.0
# Sentence 43 has a sentiment score of -0.10000000149011612
# Sentence 44 has a sentiment score of 0.0
# Sentence 45 has a sentiment score of 0.699999988079071
# Sentence 46 has a sentiment score of -0.20000000298023224
# Sentence 47 has a sentiment score of 0.30000001192092896
# Sentence 48 has a sentiment score of 0.0
# Sentence 49 has a sentiment score of -0.20000000298023224
# Sentence 50 has a sentiment score of 0.0
# Sentence 51 has a sentiment score of 0.20000000298023224
# Sentence 52 has a sentiment score of 0.0
# Sentence 53 has a sentiment score of 0.0
# Sentence 54 has a sentiment score of 0.0
# Sentence 55 has a sentiment score of 0.0
# Sentence 56 has a sentiment score of 0.6000000238418579
# Sentence 57 has a sentiment score of -0.30000001192092896
# Sentence 58 has a sentiment score of -0.30000001192092896
# Sentence 59 has a sentiment score of -0.10000000149011612
# Sentence 60 has a sentiment score of -0.699999988079071
# Sentence 61 has a sentiment score of 0.0
# Sentence 62 has a sentiment score of 0.20000000298023224
# Sentence 63 has a sentiment score of 0.8999999761581421
# Sentence 64 has a sentiment score of 0.0
# Sentence 65 has a sentiment score of 0.0
# Sentence 66 has a sentiment score of 0.10000000149011612
# Sentence 67 has a sentiment score of 0.800000011920929
# Sentence 68 has a sentiment score of 0.0
# Sentence 69 has a sentiment score of 0.0
# Sentence 70 has a sentiment score of 0.699999988079071
# Sentence 71 has a sentiment score of 0.699999988079071
# Sentence 72 has a sentiment score of 0.800000011920929
# Sentence 73 has a sentiment score of 0.800000011920929
# Sentence 74 has a sentiment score of 0.6000000238418579
# Sentence 75 has a sentiment score of -0.30000001192092896
# Sentence 76 has a sentiment score of 0.0
# Sentence 77 has a sentiment score of -0.5
# Sentence 78 has a sentiment score of -0.5
# Sentence 79 has a sentiment score of 0.30000001192092896
# Sentence 80 has a sentiment score of 0.30000001192092896
# Sentence 81 has a sentiment score of 0.0
# Sentence 82 has a sentiment score of 0.0
# Sentence 83 has a sentiment score of 0.20000000298023224
# Sentence 84 has a sentiment score of 0.10000000149011612
# Sentence 85 has a sentiment score of 0.4000000059604645
# Sentence 86 has a sentiment score of 0.699999988079071
# Sentence 87 has a sentiment score of 0.0
# Sentence 88 has a sentiment score of 0.0
# Sentence 89 has a sentiment score of 0.20000000298023224
# Sentence 90 has a sentiment score of 0.30000001192092896
# Sentence 91 has a sentiment score of 0.800000011920929
# Sentence 92 has a sentiment score of 0.0
# Sentence 93 has a sentiment score of 0.800000011920929
# Sentence 94 has a sentiment score of 0.800000011920929
# Sentence 95 has a sentiment score of 0.6000000238418579
# Sentence 96 has a sentiment score of 0.4000000059604645
# Sentence 97 has a sentiment score of -0.699999988079071
# Sentence 98 has a sentiment score of 0.20000000298023224
# Sentence 99 has a sentiment score of 0.5
# Sentence 100 has a sentiment score of 0.5
# Sentence 101 has a sentiment score of 0.8999999761581421
# Sentence 102 has a sentiment score of -0.20000000298023224
# Sentence 103 has a sentiment score of 0.8999999761581421
# Sentence 104 has a sentiment score of 0.0
# Sentence 105 has a sentiment score of 0.0
# Sentence 106 has a sentiment score of 0.30000001192092896
# Sentence 107 has a sentiment score of 0.800000011920929
# Sentence 108 has a sentiment score of 0.6000000238418579
# Sentence 109 has a sentiment score of 0.0
# Sentence 110 has a sentiment score of 0.0
# Sentence 111 has a sentiment score of -0.20000000298023224
# Sentence 112 has a sentiment score of 0.6000000238418579
# Sentence 113 has a sentiment score of -0.20000000298023224
# Sentence 114 has a sentiment score of 0.10000000149011612
# Sentence 115 has a sentiment score of 0.6000000238418579
# Sentence 116 has a sentiment score of 0.699999988079071
# Sentence 117 has a sentiment score of 0.6000000238418579
# Sentence 118 has a sentiment score of 0.0
# Sentence 119 has a sentiment score of 0.4000000059604645
# Sentence 120 has a sentiment score of 0.699999988079071
# Sentence 121 has a sentiment score of 0.20000000298023224
# Sentence 122 has a sentiment score of -0.10000000149011612
# Sentence 123 has a sentiment score of 0.6000000238418579
# Sentence 124 has a sentiment score of 0.20000000298023224
# Sentence 125 has a sentiment score of 0.5
# Sentence 126 has a sentiment score of 0.0
# Sentence 127 has a sentiment score of -0.699999988079071
# Sentence 128 has a sentiment score of 0.0
# Sentence 129 has a sentiment score of 0.0
# Sentence 130 has a sentiment score of 0.0
# Sentence 131 has a sentiment score of 0.10000000149011612
# Sentence 132 has a sentiment score of 0.6000000238418579
# Sentence 133 has a sentiment score of 0.10000000149011612
# Sentence 134 has a sentiment score of -0.6000000238418579
# Sentence 135 has a sentiment score of 0.6000000238418579
# Sentence 136 has a sentiment score of 0.5
# Sentence 137 has a sentiment score of 0.20000000298023224
# Sentence 138 has a sentiment score of 0.800000011920929
# Sentence 139 has a sentiment score of 0.8999999761581421
# Sentence 140 has a sentiment score of 0.30000001192092896
# Sentence 141 has a sentiment score of 0.699999988079071
# Sentence 142 has a sentiment score of 0.10000000149011612
# Sentence 143 has a sentiment score of 0.4000000059604645
# Sentence 144 has a sentiment score of 0.20000000298023224
# Sentence 145 has a sentiment score of 0.0
# Sentence 146 has a sentiment score of 0.4000000059604645
# Sentence 147 has a sentiment score of 0.0
# Sentence 148 has a sentiment score of -0.4000000059604645
# Sentence 149 has a sentiment score of 0.0
# Sentence 150 has a sentiment score of 0.30000001192092896
# Sentence 151 has a sentiment score of 0.20000000298023224
# Sentence 152 has a sentiment score of 0.0
# Sentence 153 has a sentiment score of 0.8999999761581421
# Sentence 154 has a sentiment score of 0.6000000238418579
# Sentence 155 has a sentiment score of -0.20000000298023224
# Sentence 156 has a sentiment score of 0.699999988079071
# Sentence 157 has a sentiment score of 0.0
# Sentence 158 has a sentiment score of 0.0
# Sentence 159 has a sentiment score of 0.800000011920929
# Sentence 160 has a sentiment score of 0.0
# Sentence 161 has a sentiment score of 0.800000011920929
# Sentence 162 has a sentiment score of 0.20000000298023224
# Sentence 163 has a sentiment score of 0.0
# Sentence 164 has a sentiment score of 0.0
# Sentence 165 has a sentiment score of 0.20000000298023224
# Sentence 166 has a sentiment score of 0.30000001192092896
# Sentence 167 has a sentiment score of 0.5
# Sentence 168 has a sentiment score of 0.10000000149011612
# Sentence 169 has a sentiment score of 0.699999988079071
# Sentence 170 has a sentiment score of 0.4000000059604645
# Sentence 171 has a sentiment score of 0.800000011920929
# Sentence 172 has a sentiment score of 0.800000011920929
# Sentence 173 has a sentiment score of 0.0
# Sentence 174 has a sentiment score of 0.10000000149011612
# Sentence 175 has a sentiment score of 0.4000000059604645
# Sentence 176 has a sentiment score of 0.4000000059604645
# Sentence 177 has a sentiment score of -0.6000000238418579
# Sentence 178 has a sentiment score of -0.30000001192092896
# Sentence 179 has a sentiment score of 0.0
# Sentence 180 has a sentiment score of 0.0
# Sentence 181 has a sentiment score of 0.699999988079071
# Sentence 182 has a sentiment score of 0.30000001192092896
# Sentence 183 has a sentiment score of 0.0
# Sentence 184 has a sentiment score of 0.800000011920929
# Sentence 185 has a sentiment score of -0.10000000149011612
# Sentence 186 has a sentiment score of 0.5
# Sentence 187 has a sentiment score of 0.8999999761581421
# Sentence 188 has a sentiment score of -0.20000000298023224
# Sentence 189 has a sentiment score of -0.4000000059604645
# Sentence 190 has a sentiment score of 0.0
# Sentence 191 has a sentiment score of 0.5
# Sentence 192 has a sentiment score of 0.0
# Sentence 193 has a sentiment score of -0.5
# Sentence 194 has a sentiment score of 0.6000000238418579
# Sentence 195 has a sentiment score of 0.20000000298023224
# Sentence 196 has a sentiment score of 0.0
# Sentence 197 has a sentiment score of -0.800000011920929
# Sentence 198 has a sentiment score of 0.800000011920929
# Sentence 199 has a sentiment score of 0.6000000238418579
# Sentence 200 has a sentiment score of 0.5
# Sentence 201 has a sentiment score of 0.0
# Sentence 202 has a sentiment score of 0.20000000298023224
# Sentence 203 has a sentiment score of 0.20000000298023224
# Sentence 204 has a sentiment score of 0.6000000238418579
# Sentence 205 has a sentiment score of 0.6000000238418579
# Sentence 206 has a sentiment score of -0.5
# Sentence 207 has a sentiment score of 0.800000011920929
# Sentence 208 has a sentiment score of 0.30000001192092896
# Sentence 209 has a sentiment score of 0.30000001192092896
# Sentence 210 has a sentiment score of -0.10000000149011612
# Sentence 211 has a sentiment score of 0.0
# Sentence 212 has a sentiment score of 0.0
# Sentence 213 has a sentiment score of 0.699999988079071
# Sentence 214 has a sentiment score of 0.10000000149011612
# Sentence 215 has a sentiment score of 0.0
# Sentence 216 has a sentiment score of 0.5
# Sentence 217 has a sentiment score of -0.4000000059604645
# Sentence 218 has a sentiment score of -0.4000000059604645
# Sentence 219 has a sentiment score of 0.0
# Sentence 220 has a sentiment score of 0.8999999761581421
# Sentence 221 has a sentiment score of 0.4000000059604645
# Sentence 222 has a sentiment score of 0.0
# Sentence 223 has a sentiment score of 0.4000000059604645
# Sentence 224 has a sentiment score of 0.0
# Sentence 225 has a sentiment score of 0.10000000149011612
# Sentence 226 has a sentiment score of 0.0
# Sentence 227 has a sentiment score of 0.699999988079071
# Sentence 228 has a sentiment score of 0.0
# Sentence 229 has a sentiment score of 0.0
# Sentence 230 has a sentiment score of 0.699999988079071
# Sentence 231 has a sentiment score of 0.20000000298023224
# Sentence 232 has a sentiment score of 0.8999999761581421
# Sentence 233 has a sentiment score of -0.30000001192092896
# Sentence 234 has a sentiment score of 0.6000000238418579
# Sentence 235 has a sentiment score of 0.800000011920929
# Sentence 236 has a sentiment score of 0.0
# Sentence 237 has a sentiment score of 0.4000000059604645
# Sentence 238 has a sentiment score of 0.699999988079071
# Sentence 239 has a sentiment score of 0.0
# Sentence 240 has a sentiment score of 0.10000000149011612
# Sentence 241 has a sentiment score of 0.0
# Sentence 242 has a sentiment score of 0.0
# Sentence 243 has a sentiment score of -0.20000000298023224
# Sentence 244 has a sentiment score of -0.30000001192092896
# Sentence 245 has a sentiment score of -0.10000000149011612
# Sentence 246 has a sentiment score of 0.20000000298023224
# Sentence 247 has a sentiment score of 0.30000001192092896
# Sentence 248 has a sentiment score of 0.699999988079071
# Sentence 249 has a sentiment score of 0.30000001192092896
# Sentence 250 has a sentiment score of 0.0
# Sentence 251 has a sentiment score of -0.10000000149011612
# Sentence 252 has a sentiment score of 0.6000000238418579
# Sentence 253 has a sentiment score of 0.699999988079071
# Sentence 254 has a sentiment score of 0.800000011920929
# Sentence 255 has a sentiment score of 0.20000000298023224
# Sentence 256 has a sentiment score of 0.10000000149011612
# Sentence 257 has a sentiment score of 0.30000001192092896
# Sentence 258 has a sentiment score of 0.20000000298023224
# Sentence 259 has a sentiment score of 0.0
# Sentence 260 has a sentiment score of 0.10000000149011612
# Sentence 261 has a sentiment score of 0.0
# Sentence 262 has a sentiment score of 0.30000001192092896
# Sentence 263 has a sentiment score of 0.20000000298023224
# Sentence 264 has a sentiment score of 0.4000000059604645
# Sentence 265 has a sentiment score of 0.699999988079071
# Sentence 266 has a sentiment score of 0.0
# Sentence 267 has a sentiment score of 0.30000001192092896
# Sentence 268 has a sentiment score of 0.0
# Sentence 269 has a sentiment score of 0.20000000298023224
# Sentence 270 has a sentiment score of 0.800000011920929
# Sentence 271 has a sentiment score of 0.20000000298023224
# Sentence 272 has a sentiment score of 0.4000000059604645
# Sentence 273 has a sentiment score of 0.0
# Sentence 274 has a sentiment score of 0.0
# Sentence 275 has a sentiment score of 0.10000000149011612
# Sentence 276 has a sentiment score of 0.800000011920929
# Sentence 277 has a sentiment score of 0.8999999761581421
# Sentence 278 has a sentiment score of 0.0
# Sentence 279 has a sentiment score of 0.20000000298023224
# Sentence 280 has a sentiment score of 0.0
# Sentence 281 has a sentiment score of 0.0
# Sentence 282 has a sentiment score of 0.0
# Sentence 283 has a sentiment score of 0.6000000238418579
# Sentence 284 has a sentiment score of 0.6000000238418579
# Sentence 285 has a sentiment score of 0.0
# Sentence 286 has a sentiment score of -0.6000000238418579
# Sentence 287 has a sentiment score of 0.800000011920929
# Sentence 288 has a sentiment score of 0.4000000059604645
# Sentence 289 has a sentiment score of 0.20000000298023224
# Sentence 290 has a sentiment score of 0.0
# Sentence 291 has a sentiment score of 0.699999988079071
# Sentence 292 has a sentiment score of 0.20000000298023224
# Sentence 293 has a sentiment score of 0.0
# Sentence 294 has a sentiment score of 0.0
# Sentence 295 has a sentiment score of 0.699999988079071
# Sentence 296 has a sentiment score of 0.4000000059604645
# Sentence 297 has a sentiment score of 0.0
# Sentence 298 has a sentiment score of 0.699999988079071
# Sentence 299 has a sentiment score of 0.0
# Sentence 300 has a sentiment score of 0.0
# Sentence 301 has a sentiment score of 0.800000011920929
# Sentence 302 has a sentiment score of 0.5
# Sentence 303 has a sentiment score of 0.30000001192092896
# Sentence 304 has a sentiment score of -0.10000000149011612
# Sentence 305 has a sentiment score of 0.4000000059604645
# Sentence 306 has a sentiment score of 0.20000000298023224
# Sentence 307 has a sentiment score of 0.4000000059604645
# Sentence 308 has a sentiment score of 0.30000001192092896
# Sentence 309 has a sentiment score of 0.5
# Sentence 310 has a sentiment score of -0.20000000298023224
# Sentence 311 has a sentiment score of 0.699999988079071
# Sentence 312 has a sentiment score of 0.5
# Sentence 313 has a sentiment score of -0.4000000059604645
# Sentence 314 has a sentiment score of -0.20000000298023224
# Sentence 315 has a sentiment score of 0.6000000238418579
# Sentence 316 has a sentiment score of -0.5
# Sentence 317 has a sentiment score of -0.5
# Sentence 318 has a sentiment score of -0.10000000149011612
# Sentence 319 has a sentiment score of 0.5
# Sentence 320 has a sentiment score of 0.0
# Sentence 321 has a sentiment score of 0.4000000059604645
# Sentence 322 has a sentiment score of 0.0
# Sentence 323 has a sentiment score of 0.5
# Sentence 324 has a sentiment score of 0.20000000298023224
# Sentence 325 has a sentiment score of -0.10000000149011612
# Sentence 326 has a sentiment score of 0.6000000238418579
# Sentence 327 has a sentiment score of 0.30000001192092896
# Sentence 328 has a sentiment score of 0.0
# Sentence 329 has a sentiment score of 0.10000000149011612
# Sentence 330 has a sentiment score of 0.6000000238418579
# Sentence 331 has a sentiment score of 0.8999999761581421
# Sentence 332 has a sentiment score of 0.20000000298023224
# Sentence 333 has a sentiment score of 0.8999999761581421
# Sentence 334 has a sentiment score of 0.800000011920929
# Sentence 335 has a sentiment score of 0.20000000298023224
# Sentence 336 has a sentiment score of 0.5
# Sentence 337 has a sentiment score of 0.699999988079071
# Sentence 338 has a sentiment score of 0.0
# Sentence 339 has a sentiment score of 0.10000000149011612
# Sentence 340 has a sentiment score of 0.10000000149011612
# Sentence 341 has a sentiment score of 0.5
# Sentence 342 has a sentiment score of 0.10000000149011612
# Sentence 343 has a sentiment score of 0.0
# Sentence 344 has a sentiment score of 0.0
# Sentence 345 has a sentiment score of 0.10000000149011612
# Sentence 346 has a sentiment score of 0.5
# Sentence 347 has a sentiment score of 0.10000000149011612
# Sentence 348 has a sentiment score of 0.0
# Sentence 349 has a sentiment score of 0.6000000238418579
# Sentence 350 has a sentiment score of 0.6000000238418579
# Sentence 351 has a sentiment score of -0.30000001192092896
# Sentence 352 has a sentiment score of -0.4000000059604645
# Sentence 353 has a sentiment score of 0.699999988079071
# Sentence 354 has a sentiment score of 0.800000011920929
# Sentence 355 has a sentiment score of 0.6000000238418579
# Sentence 356 has a sentiment score of 0.0
# Sentence 357 has a sentiment score of 0.6000000238418579
# Sentence 358 has a sentiment score of 0.0
# Sentence 359 has a sentiment score of 0.10000000149011612
# Sentence 360 has a sentiment score of 0.10000000149011612
# Sentence 361 has a sentiment score of 0.4000000059604645
# Sentence 362 has a sentiment score of 0.4000000059604645
# Sentence 363 has a sentiment score of 0.699999988079071
# Sentence 364 has a sentiment score of 0.10000000149011612
# Sentence 365 has a sentiment score of -0.10000000149011612
# Sentence 366 has a sentiment score of -0.5
# Sentence 367 has a sentiment score of 0.0
# Sentence 368 has a sentiment score of 0.0
# Sentence 369 has a sentiment score of 0.10000000149011612
# Sentence 370 has a sentiment score of -0.20000000298023224
# Sentence 371 has a sentiment score of -0.10000000149011612
# Sentence 372 has a sentiment score of 0.800000011920929
# Sentence 373 has a sentiment score of 0.800000011920929
# Sentence 374 has a sentiment score of 0.10000000149011612
# Sentence 375 has a sentiment score of 0.0
# Sentence 376 has a sentiment score of -0.20000000298023224
# Sentence 377 has a sentiment score of 0.5
# Sentence 378 has a sentiment score of 0.4000000059604645
# Sentence 379 has a sentiment score of 0.30000001192092896
# Sentence 380 has a sentiment score of 0.10000000149011612
# Sentence 381 has a sentiment score of 0.0
# Sentence 382 has a sentiment score of 0.0
# Sentence 383 has a sentiment score of -0.10000000149011612
# Sentence 384 has a sentiment score of 0.30000001192092896
# Sentence 385 has a sentiment score of 0.20000000298023224
# Sentence 386 has a sentiment score of -0.10000000149011612
# Sentence 387 has a sentiment score of 0.4000000059604645
# Sentence 388 has a sentiment score of 0.0
# Sentence 389 has a sentiment score of 0.8999999761581421
# Sentence 390 has a sentiment score of 0.30000001192092896
# Sentence 391 has a sentiment score of 0.0
# Sentence 392 has a sentiment score of 0.20000000298023224
# Sentence 393 has a sentiment score of -0.20000000298023224
# Sentence 394 has a sentiment score of 0.4000000059604645
# Sentence 395 has a sentiment score of 0.0
# Sentence 396 has a sentiment score of -0.20000000298023224
# Sentence 397 has a sentiment score of 0.5
# Sentence 398 has a sentiment score of -0.20000000298023224
# Sentence 399 has a sentiment score of -0.6000000238418579
# Sentence 400 has a sentiment score of 0.6000000238418579
# Sentence 401 has a sentiment score of 0.0
# Sentence 402 has a sentiment score of 0.699999988079071
# Sentence 403 has a sentiment score of -0.5
# Sentence 404 has a sentiment score of 0.0
# Sentence 405 has a sentiment score of 0.0
# Sentence 406 has a sentiment score of 0.0
# Sentence 407 has a sentiment score of 0.0
# Sentence 408 has a sentiment score of 0.10000000149011612
# Sentence 409 has a sentiment score of 0.0
# Sentence 410 has a sentiment score of 0.0
# Sentence 411 has a sentiment score of -0.5
# Sentence 412 has a sentiment score of -0.20000000298023224
# Sentence 413 has a sentiment score of 0.0
# Sentence 414 has a sentiment score of 0.6000000238418579
# Sentence 415 has a sentiment score of 0.0
# Sentence 416 has a sentiment score of 0.0
# Sentence 417 has a sentiment score of 0.0
# Sentence 418 has a sentiment score of 0.5
# Sentence 419 has a sentiment score of 0.800000011920929
# Sentence 420 has a sentiment score of -0.10000000149011612
# Sentence 421 has a sentiment score of 0.30000001192092896
# Sentence 422 has a sentiment score of 0.0
# Sentence 423 has a sentiment score of 0.10000000149011612
# Sentence 424 has a sentiment score of -0.30000001192092896
# Sentence 425 has a sentiment score of 0.8999999761581421
# Sentence 426 has a sentiment score of 0.8999999761581421
# Sentence 427 has a sentiment score of 0.8999999761581421
# Sentence 428 has a sentiment score of 0.699999988079071
# Sentence 429 has a sentiment score of 0.20000000298023224
# Sentence 430 has a sentiment score of 0.5
# Sentence 431 has a sentiment score of 0.699999988079071
# Sentence 432 has a sentiment score of -0.4000000059604645
# Sentence 433 has a sentiment score of -0.10000000149011612
# Sentence 434 has a sentiment score of 0.0
# Sentence 435 has a sentiment score of 0.0
# Sentence 436 has a sentiment score of 0.0
# Sentence 437 has a sentiment score of 0.30000001192092896
# Sentence 438 has a sentiment score of 0.0
# Sentence 439 has a sentiment score of 0.5
# Sentence 440 has a sentiment score of 0.0
# Sentence 441 has a sentiment score of 0.0
# Sentence 442 has a sentiment score of 0.0
# Sentence 443 has a sentiment score of 0.20000000298023224
# Sentence 444 has a sentiment score of 0.0
# Sentence 445 has a sentiment score of 0.0
# Sentence 446 has a sentiment score of 0.0
# Sentence 447 has a sentiment score of 0.5
# Sentence 448 has a sentiment score of 0.800000011920929
# Sentence 449 has a sentiment score of 0.0
# Sentence 450 has a sentiment score of 0.699999988079071
# Sentence 451 has a sentiment score of 0.0
# Sentence 452 has a sentiment score of 0.10000000149011612
# Sentence 453 has a sentiment score of -0.5
# Sentence 454 has a sentiment score of 0.20000000298023224
# Sentence 455 has a sentiment score of 0.4000000059604645
# Sentence 456 has a sentiment score of -0.30000001192092896
# Sentence 457 has a sentiment score of -0.10000000149011612
# Sentence 458 has a sentiment score of 0.0
# Sentence 459 has a sentiment score of 0.0
# Sentence 460 has a sentiment score of 0.0
# Sentence 461 has a sentiment score of -0.30000001192092896
# Sentence 462 has a sentiment score of 0.0
# Sentence 463 has a sentiment score of 0.10000000149011612
# Sentence 464 has a sentiment score of -0.30000001192092896
# Sentence 465 has a sentiment score of 0.30000001192092896
# Sentence 466 has a sentiment score of 0.0
# Sentence 467 has a sentiment score of 0.4000000059604645
# Sentence 468 has a sentiment score of 0.0
# Sentence 469 has a sentiment score of 0.0
# Sentence 470 has a sentiment score of 0.10000000149011612
# Sentence 471 has a sentiment score of 0.6000000238418579
# Sentence 472 has a sentiment score of 0.699999988079071
# Sentence 473 has a sentiment score of -0.10000000149011612
# Sentence 474 has a sentiment score of 0.800000011920929
# Sentence 475 has a sentiment score of -0.30000001192092896
# Sentence 476 has a sentiment score of -0.10000000149011612
# Sentence 477 has a sentiment score of 0.699999988079071
# Sentence 478 has a sentiment score of -0.5
# Sentence 479 has a sentiment score of 0.0
# Sentence 480 has a sentiment score of 0.0
# Sentence 481 has a sentiment score of 0.20000000298023224
# Sentence 482 has a sentiment score of 0.0
# Sentence 483 has a sentiment score of 0.0
# Sentence 484 has a sentiment score of 0.0
# Sentence 485 has a sentiment score of 0.0
# Sentence 486 has a sentiment score of 0.0
# Sentence 487 has a sentiment score of 0.6000000238418579
# Sentence 488 has a sentiment score of 0.0
# Sentence 489 has a sentiment score of 0.10000000149011612
# Sentence 490 has a sentiment score of 0.0
# Sentence 491 has a sentiment score of 0.4000000059604645
# Sentence 492 has a sentiment score of 0.699999988079071
# Sentence 493 has a sentiment score of 0.10000000149011612
# Sentence 494 has a sentiment score of 0.0
# Sentence 495 has a sentiment score of 0.0
# Sentence 496 has a sentiment score of 0.6000000238418579
# Sentence 497 has a sentiment score of 0.0
# Sentence 498 has a sentiment score of 0.20000000298023224
# Sentence 499 has a sentiment score of 0.10000000149011612
# Sentence 500 has a sentiment score of 0.0
# Sentence 501 has a sentiment score of -0.20000000298023224
# Sentence 502 has a sentiment score of 0.0
# Sentence 503 has a sentiment score of 0.6000000238418579
# Sentence 504 has a sentiment score of 0.10000000149011612
# Sentence 505 has a sentiment score of 0.4000000059604645
# Sentence 506 has a sentiment score of 0.0
# Sentence 507 has a sentiment score of 0.800000011920929
# Sentence 508 has a sentiment score of 0.10000000149011612
# Sentence 509 has a sentiment score of 0.6000000238418579
# Sentence 510 has a sentiment score of 0.30000001192092896
# Sentence 511 has a sentiment score of 0.4000000059604645
# Sentence 512 has a sentiment score of 0.800000011920929
# Sentence 513 has a sentiment score of 0.10000000149011612
# Sentence 514 has a sentiment score of 0.0
# Sentence 515 has a sentiment score of 0.8999999761581421
# Sentence 516 has a sentiment score of 0.0
# Sentence 517 has a sentiment score of 0.800000011920929
# Sentence 518 has a sentiment score of 0.0
# Sentence 519 has a sentiment score of 0.6000000238418579
# Sentence 520 has a sentiment score of 0.0
# Sentence 521 has a sentiment score of 0.0
# Sentence 522 has a sentiment score of 0.10000000149011612
# Sentence 523 has a sentiment score of 0.0
# Sentence 524 has a sentiment score of 0.0
# Sentence 525 has a sentiment score of 0.699999988079071
# Sentence 526 has a sentiment score of -0.20000000298023224
# Sentence 527 has a sentiment score of 0.20000000298023224
# Sentence 528 has a sentiment score of 0.4000000059604645
# Sentence 529 has a sentiment score of -0.5
# Sentence 530 has a sentiment score of -0.4000000059604645
# Sentence 531 has a sentiment score of 0.699999988079071
# Sentence 532 has a sentiment score of -0.5
# Sentence 533 has a sentiment score of -0.5
# Sentence 534 has a sentiment score of 0.0
# Sentence 535 has a sentiment score of 0.0
# Sentence 536 has a sentiment score of 0.0
# Sentence 537 has a sentiment score of -0.20000000298023224
# Sentence 538 has a sentiment score of -0.10000000149011612
# Sentence 539 has a sentiment score of 0.0
# Sentence 540 has a sentiment score of -0.10000000149011612
# Sentence 541 has a sentiment score of 0.10000000149011612
# Sentence 542 has a sentiment score of -0.10000000149011612
# Sentence 543 has a sentiment score of 0.0
# Sentence 544 has a sentiment score of 0.30000001192092896
# Sentence 545 has a sentiment score of 0.20000000298023224
# Sentence 546 has a sentiment score of 0.0
# Sentence 547 has a sentiment score of 0.10000000149011612
# Sentence 548 has a sentiment score of 0.20000000298023224
# Sentence 549 has a sentiment score of 0.699999988079071
# Sentence 550 has a sentiment score of 0.0
# Sentence 551 has a sentiment score of 0.30000001192092896
# Sentence 552 has a sentiment score of 0.800000011920929
# Sentence 553 has a sentiment score of 0.10000000149011612
# Sentence 554 has a sentiment score of 0.5
# Sentence 555 has a sentiment score of 0.4000000059604645
# Sentence 556 has a sentiment score of -0.10000000149011612
# Sentence 557 has a sentiment score of 0.30000001192092896
# Sentence 558 has a sentiment score of 0.6000000238418579
# Sentence 559 has a sentiment score of 0.20000000298023224
# Sentence 560 has a sentiment score of 0.4000000059604645
# Sentence 561 has a sentiment score of 0.0
# Sentence 562 has a sentiment score of 0.10000000149011612
# Sentence 563 has a sentiment score of 0.0
# Sentence 564 has a sentiment score of 0.10000000149011612
# Sentence 565 has a sentiment score of 0.10000000149011612
# Sentence 566 has a sentiment score of 0.0
# Sentence 567 has a sentiment score of 0.699999988079071
# Sentence 568 has a sentiment score of 0.699999988079071
# Sentence 569 has a sentiment score of 0.20000000298023224
# Sentence 570 has a sentiment score of 0.20000000298023224
# Sentence 571 has a sentiment score of 0.0
# Sentence 572 has a sentiment score of 0.6000000238418579
# Sentence 573 has a sentiment score of 0.0
# Sentence 574 has a sentiment score of 0.800000011920929
# Sentence 575 has a sentiment score of 0.800000011920929
# Sentence 576 has a sentiment score of 0.0
# Sentence 577 has a sentiment score of 0.0
# Sentence 578 has a sentiment score of 0.0
# Sentence 579 has a sentiment score of 0.4000000059604645
# Sentence 580 has a sentiment score of 0.0
# Sentence 581 has a sentiment score of 0.20000000298023224
# Sentence 582 has a sentiment score of 0.0
# Sentence 583 has a sentiment score of 0.0
# Sentence 584 has a sentiment score of 0.30000001192092896
# Sentence 585 has a sentiment score of 0.6000000238418579
# Sentence 586 has a sentiment score of -0.20000000298023224
# Sentence 587 has a sentiment score of 0.5
# Sentence 588 has a sentiment score of -0.800000011920929
# Sentence 589 has a sentiment score of 0.0
# Sentence 590 has a sentiment score of -0.30000001192092896
# Sentence 591 has a sentiment score of 0.0
# Sentence 592 has a sentiment score of 0.6000000238418579
# Sentence 593 has a sentiment score of 0.0
# Sentence 594 has a sentiment score of -0.800000011920929
# Sentence 595 has a sentiment score of -0.20000000298023224
# Sentence 596 has a sentiment score of 0.30000001192092896
# Sentence 597 has a sentiment score of 0.0
# Sentence 598 has a sentiment score of 0.0
# Sentence 599 has a sentiment score of -0.20000000298023224
# Sentence 600 has a sentiment score of 0.4000000059604645
# Sentence 601 has a sentiment score of 0.4000000059604645
# Sentence 602 has a sentiment score of 0.0
# Sentence 603 has a sentiment score of -0.10000000149011612
# Sentence 604 has a sentiment score of 0.0
# Sentence 605 has a sentiment score of -0.20000000298023224
# Sentence 606 has a sentiment score of -0.5
# Sentence 607 has a sentiment score of -0.10000000149011612
# Sentence 608 has a sentiment score of 0.800000011920929
# Sentence 609 has a sentiment score of 0.20000000298023224
# Sentence 610 has a sentiment score of 0.4000000059604645
# Sentence 611 has a sentiment score of 0.0
# Sentence 612 has a sentiment score of 0.0
# Sentence 613 has a sentiment score of -0.800000011920929
# Sentence 614 has a sentiment score of 0.4000000059604645
# Sentence 615 has a sentiment score of -0.5
# Sentence 616 has a sentiment score of 0.30000001192092896
# Sentence 617 has a sentiment score of 0.0
# Sentence 618 has a sentiment score of 0.4000000059604645
# Sentence 619 has a sentiment score of 0.5
# Sentence 620 has a sentiment score of 0.20000000298023224
# Sentence 621 has a sentiment score of 0.699999988079071
# Sentence 622 has a sentiment score of -0.699999988079071
# Sentence 623 has a sentiment score of -0.10000000149011612
# Sentence 624 has a sentiment score of 0.20000000298023224
# Sentence 625 has a sentiment score of -0.10000000149011612
# Sentence 626 has a sentiment score of 0.20000000298023224
# Sentence 627 has a sentiment score of 0.699999988079071
# Sentence 628 has a sentiment score of -0.5
# Sentence 629 has a sentiment score of 0.30000001192092896
# Sentence 630 has a sentiment score of 0.8999999761581421
# Sentence 631 has a sentiment score of -0.20000000298023224
# Sentence 632 has a sentiment score of 0.4000000059604645
# Sentence 633 has a sentiment score of 0.10000000149011612
# Sentence 634 has a sentiment score of 0.0
# Sentence 635 has a sentiment score of 0.800000011920929
# Sentence 636 has a sentiment score of 0.0
# Sentence 637 has a sentiment score of 0.6000000238418579
# Sentence 638 has a sentiment score of 0.0
# Sentence 639 has a sentiment score of 0.0
# Sentence 640 has a sentiment score of -0.10000000149011612
# Sentence 641 has a sentiment score of -0.30000001192092896
# Sentence 642 has a sentiment score of -0.6000000238418579
# Sentence 643 has a sentiment score of 0.0
# Sentence 644 has a sentiment score of -0.4000000059604645
# Sentence 645 has a sentiment score of 0.0
# Sentence 646 has a sentiment score of 0.0
# Sentence 647 has a sentiment score of 0.4000000059604645
# Sentence 648 has a sentiment score of -0.20000000298023224
# Sentence 649 has a sentiment score of 0.5
# Sentence 650 has a sentiment score of 0.0
# Sentence 651 has a sentiment score of 0.0
# Sentence 652 has a sentiment score of 0.0
# Sentence 653 has a sentiment score of 0.0
# Sentence 654 has a sentiment score of -0.10000000149011612
# Sentence 655 has a sentiment score of -0.10000000149011612
# Sentence 656 has a sentiment score of 0.0
# Sentence 657 has a sentiment score of 0.10000000149011612
# Sentence 658 has a sentiment score of -0.30000001192092896
# Sentence 659 has a sentiment score of 0.4000000059604645
# Sentence 660 has a sentiment score of 0.0
# Sentence 661 has a sentiment score of 0.30000001192092896
# Sentence 662 has a sentiment score of 0.699999988079071
# Sentence 663 has a sentiment score of -0.30000001192092896
# Sentence 664 has a sentiment score of -0.699999988079071
# Sentence 665 has a sentiment score of -0.20000000298023224
# Sentence 666 has a sentiment score of 0.6000000238418579
# Sentence 667 has a sentiment score of 0.6000000238418579
# Sentence 668 has a sentiment score of 0.6000000238418579
# Sentence 669 has a sentiment score of 0.0
# Sentence 670 has a sentiment score of 0.0
# Sentence 671 has a sentiment score of -0.5
# Sentence 672 has a sentiment score of 0.30000001192092896
# Sentence 673 has a sentiment score of 0.30000001192092896
# Sentence 674 has a sentiment score of -0.10000000149011612
# Sentence 675 has a sentiment score of -0.800000011920929
# Sentence 676 has a sentiment score of -0.4000000059604645
# Sentence 677 has a sentiment score of 0.20000000298023224
# Sentence 678 has a sentiment score of 0.10000000149011612
# Sentence 679 has a sentiment score of 0.0
# Sentence 680 has a sentiment score of -0.30000001192092896
# Sentence 681 has a sentiment score of -0.4000000059604645
# Sentence 682 has a sentiment score of 0.699999988079071
# Sentence 683 has a sentiment score of -0.699999988079071
# Sentence 684 has a sentiment score of 0.6000000238418579
# Sentence 685 has a sentiment score of -0.20000000298023224
# Sentence 686 has a sentiment score of 0.4000000059604645
# Sentence 687 has a sentiment score of 0.10000000149011612
# Sentence 688 has a sentiment score of 0.10000000149011612
# Sentence 689 has a sentiment score of 0.30000001192092896
# Sentence 690 has a sentiment score of 0.0
# Sentence 691 has a sentiment score of -0.20000000298023224
# Sentence 692 has a sentiment score of 0.20000000298023224
# Sentence 693 has a sentiment score of -0.30000001192092896
# Sentence 694 has a sentiment score of 0.30000001192092896
# Sentence 695 has a sentiment score of 0.10000000149011612
# Sentence 696 has a sentiment score of 0.5
# Sentence 697 has a sentiment score of 0.10000000149011612
# Sentence 698 has a sentiment score of 0.30000001192092896
# Sentence 699 has a sentiment score of 0.30000001192092896
# Sentence 700 has a sentiment score of 0.4000000059604645
# Sentence 701 has a sentiment score of 0.30000001192092896
# Sentence 702 has a sentiment score of 0.5
# Sentence 703 has a sentiment score of 0.0
# Sentence 704 has a sentiment score of 0.0
# Sentence 705 has a sentiment score of 0.20000000298023224
# Sentence 706 has a sentiment score of -0.6000000238418579
# Sentence 707 has a sentiment score of 0.10000000149011612
# Sentence 708 has a sentiment score of -0.699999988079071
# Sentence 709 has a sentiment score of 0.0
# Sentence 710 has a sentiment score of 0.20000000298023224
# Sentence 711 has a sentiment score of 0.10000000149011612
# Sentence 712 has a sentiment score of 0.0
# Sentence 713 has a sentiment score of -0.20000000298023224
# Sentence 714 has a sentiment score of 0.4000000059604645
# Sentence 715 has a sentiment score of 0.0
# Sentence 716 has a sentiment score of 0.6000000238418579
# Sentence 717 has a sentiment score of 0.800000011920929
# Sentence 718 has a sentiment score of 0.6000000238418579
# Sentence 719 has a sentiment score of 0.6000000238418579
# Sentence 720 has a sentiment score of 0.0
# Sentence 721 has a sentiment score of 0.0
# Sentence 722 has a sentiment score of 0.699999988079071
# Sentence 723 has a sentiment score of 0.10000000149011612
# Sentence 724 has a sentiment score of -0.30000001192092896
# Sentence 725 has a sentiment score of 0.6000000238418579
# Sentence 726 has a sentiment score of 0.0
# Sentence 727 has a sentiment score of -0.30000001192092896
# Sentence 728 has a sentiment score of 0.5
# Sentence 729 has a sentiment score of 0.20000000298023224
# Sentence 730 has a sentiment score of 0.0
# Sentence 731 has a sentiment score of 0.699999988079071
# Sentence 732 has a sentiment score of 0.30000001192092896
# Sentence 733 has a sentiment score of 0.699999988079071
# Sentence 734 has a sentiment score of 0.8999999761581421
# Sentence 735 has a sentiment score of 0.8999999761581421
# Sentence 736 has a sentiment score of 0.0
# Sentence 737 has a sentiment score of 0.699999988079071
# Sentence 738 has a sentiment score of 0.5
# Sentence 739 has a sentiment score of 0.5
# Sentence 740 has a sentiment score of 0.4000000059604645
# Sentence 741 has a sentiment score of 0.5
# Sentence 742 has a sentiment score of 0.30000001192092896
# Sentence 743 has a sentiment score of 0.10000000149011612
# Sentence 744 has a sentiment score of 0.699999988079071
# Sentence 745 has a sentiment score of 0.0
# Sentence 746 has a sentiment score of 0.4000000059604645
# Sentence 747 has a sentiment score of 0.0
# Sentence 748 has a sentiment score of 0.10000000149011612
# Sentence 749 has a sentiment score of 0.5
# Sentence 750 has a sentiment score of 0.4000000059604645
# Sentence 751 has a sentiment score of 0.6000000238418579
# Sentence 752 has a sentiment score of 0.0
# Sentence 753 has a sentiment score of 0.0
# Sentence 754 has a sentiment score of 0.20000000298023224
# Sentence 755 has a sentiment score of 0.0
# Sentence 756 has a sentiment score of 0.4000000059604645
# Sentence 757 has a sentiment score of -0.10000000149011612
# Sentence 758 has a sentiment score of 0.10000000149011612
# Sentence 759 has a sentiment score of 0.699999988079071
# Sentence 760 has a sentiment score of 0.5
# Sentence 761 has a sentiment score of 0.0
# Sentence 762 has a sentiment score of 0.4000000059604645
# Sentence 763 has a sentiment score of 0.0
# Sentence 764 has a sentiment score of 0.10000000149011612
# Sentence 765 has a sentiment score of 0.10000000149011612
# Sentence 766 has a sentiment score of 0.0
# Sentence 767 has a sentiment score of -0.20000000298023224
# Sentence 768 has a sentiment score of -0.6000000238418579
# Sentence 769 has a sentiment score of 0.0
# Sentence 770 has a sentiment score of 0.0
# Sentence 771 has a sentiment score of 0.20000000298023224
# Sentence 772 has a sentiment score of 0.20000000298023224
# Sentence 773 has a sentiment score of 0.6000000238418579
# Sentence 774 has a sentiment score of 0.10000000149011612
# Sentence 775 has a sentiment score of 0.0
# Sentence 776 has a sentiment score of 0.6000000238418579
# Sentence 777 has a sentiment score of 0.5
# Sentence 778 has a sentiment score of -0.6000000238418579
# Sentence 779 has a sentiment score of -0.10000000149011612
# Sentence 780 has a sentiment score of 0.5
# Sentence 781 has a sentiment score of -0.10000000149011612
# Sentence 782 has a sentiment score of 0.6000000238418579
# Sentence 783 has a sentiment score of -0.800000011920929
# Sentence 784 has a sentiment score of 0.5
# Sentence 785 has a sentiment score of 0.10000000149011612
# Sentence 786 has a sentiment score of 0.0
# Sentence 787 has a sentiment score of -0.30000001192092896
# Sentence 788 has a sentiment score of -0.4000000059604645
# Sentence 789 has a sentiment score of 0.5
# Sentence 790 has a sentiment score of 0.0
# Sentence 791 has a sentiment score of -0.6000000238418579
# Sentence 792 has a sentiment score of 0.800000011920929
# Sentence 793 has a sentiment score of 0.4000000059604645
# Sentence 794 has a sentiment score of 0.6000000238418579
# Sentence 795 has a sentiment score of 0.5
# Sentence 796 has a sentiment score of -0.5
# Sentence 797 has a sentiment score of 0.0
# Sentence 798 has a sentiment score of 0.0
# Sentence 799 has a sentiment score of 0.699999988079071
# Sentence 800 has a sentiment score of 0.4000000059604645
# Sentence 801 has a sentiment score of 0.6000000238418579
# Sentence 802 has a sentiment score of 0.20000000298023224
# Sentence 803 has a sentiment score of 0.5
# Sentence 804 has a sentiment score of 0.20000000298023224
# Sentence 805 has a sentiment score of 0.0
# Sentence 806 has a sentiment score of 0.20000000298023224
# Sentence 807 has a sentiment score of 0.0
# Sentence 808 has a sentiment score of -0.30000001192092896
# Sentence 809 has a sentiment score of 0.0
# Sentence 810 has a sentiment score of -0.30000001192092896
# Sentence 811 has a sentiment score of 0.800000011920929
# Sentence 812 has a sentiment score of 0.20000000298023224
# Sentence 813 has a sentiment score of 0.0
# Sentence 814 has a sentiment score of 0.0
# Sentence 815 has a sentiment score of 0.0
# Sentence 816 has a sentiment score of 0.0
# Sentence 817 has a sentiment score of 0.0
# Sentence 818 has a sentiment score of 0.0
# Sentence 819 has a sentiment score of 0.0
# Sentence 820 has a sentiment score of 0.0
# Sentence 821 has a sentiment score of -0.5
# Sentence 822 has a sentiment score of -0.30000001192092896
# Sentence 823 has a sentiment score of -0.5
# Sentence 824 has a sentiment score of 0.0
# Sentence 825 has a sentiment score of -0.10000000149011612
# Sentence 826 has a sentiment score of 0.10000000149011612
# Sentence 827 has a sentiment score of 0.699999988079071
# Sentence 828 has a sentiment score of -0.4000000059604645
# Sentence 829 has a sentiment score of 0.0
# Sentence 830 has a sentiment score of 0.0
# Sentence 831 has a sentiment score of 0.30000001192092896
# Sentence 832 has a sentiment score of 0.0
# Sentence 833 has a sentiment score of 0.0
# Sentence 834 has a sentiment score of 0.20000000298023224
# Sentence 835 has a sentiment score of -0.20000000298023224
# Sentence 836 has a sentiment score of -0.10000000149011612
# Sentence 837 has a sentiment score of -0.10000000149011612
# Sentence 838 has a sentiment score of 0.0
# Sentence 839 has a sentiment score of 0.0
# Sentence 840 has a sentiment score of 0.5
# Sentence 841 has a sentiment score of 0.10000000149011612
# Sentence 842 has a sentiment score of 0.5
# Sentence 843 has a sentiment score of 0.0
# Sentence 844 has a sentiment score of 0.0
# Sentence 845 has a sentiment score of 0.0
# Sentence 846 has a sentiment score of 0.8999999761581421
# Sentence 847 has a sentiment score of -0.10000000149011612
# Sentence 848 has a sentiment score of 0.30000001192092896
# Sentence 849 has a sentiment score of 0.5
# Sentence 850 has a sentiment score of 0.10000000149011612
# Sentence 851 has a sentiment score of 0.8999999761581421
# Sentence 852 has a sentiment score of 0.5
# Sentence 853 has a sentiment score of 0.699999988079071
# Sentence 854 has a sentiment score of 0.8999999761581421
# Sentence 855 has a sentiment score of 0.30000001192092896
# Sentence 856 has a sentiment score of 0.699999988079071
# Sentence 857 has a sentiment score of 0.4000000059604645
# Sentence 858 has a sentiment score of -0.30000001192092896
# Sentence 859 has a sentiment score of 0.30000001192092896
# Sentence 860 has a sentiment score of -0.10000000149011612
# Sentence 861 has a sentiment score of -0.4000000059604645
# Sentence 862 has a sentiment score of 0.0
# Sentence 863 has a sentiment score of 0.0
# Sentence 864 has a sentiment score of 0.0
# Sentence 865 has a sentiment score of 0.0
# Sentence 866 has a sentiment score of 0.699999988079071
# Sentence 867 has a sentiment score of -0.30000001192092896
# Sentence 868 has a sentiment score of 0.6000000238418579
# Sentence 869 has a sentiment score of -0.5
# Sentence 870 has a sentiment score of 0.699999988079071
# Sentence 871 has a sentiment score of 0.699999988079071
# Sentence 872 has a sentiment score of 0.8999999761581421
# Sentence 873 has a sentiment score of 0.800000011920929
# Sentence 874 has a sentiment score of 0.800000011920929
# Sentence 875 has a sentiment score of 0.0
# Sentence 876 has a sentiment score of 0.0
# Sentence 877 has a sentiment score of 0.5
# Sentence 878 has a sentiment score of 0.0
# Sentence 879 has a sentiment score of 0.10000000149011612
# Sentence 880 has a sentiment score of 0.6000000238418579
# Sentence 881 has a sentiment score of -0.20000000298023224
# Sentence 882 has a sentiment score of 0.20000000298023224
# Sentence 883 has a sentiment score of 0.4000000059604645
# Sentence 884 has a sentiment score of 0.0
# Sentence 885 has a sentiment score of 0.6000000238418579
# Sentence 886 has a sentiment score of -0.20000000298023224
# Sentence 887 has a sentiment score of 0.6000000238418579
# Sentence 888 has a sentiment score of 0.4000000059604645
# Sentence 889 has a sentiment score of 0.4000000059604645
# Sentence 890 has a sentiment score of 0.6000000238418579
# Sentence 891 has a sentiment score of -0.10000000149011612
# Sentence 892 has a sentiment score of 0.0
# Sentence 893 has a sentiment score of 0.10000000149011612
# Sentence 894 has a sentiment score of -0.4000000059604645
# Sentence 895 has a sentiment score of -0.6000000238418579
# Sentence 896 has a sentiment score of 0.20000000298023224
# Sentence 897 has a sentiment score of 0.8999999761581421
# Sentence 898 has a sentiment score of 0.10000000149011612
# Sentence 899 has a sentiment score of 0.10000000149011612
# Sentence 900 has a sentiment score of 0.0
# Sentence 901 has a sentiment score of -0.30000001192092896
# Sentence 902 has a sentiment score of 0.800000011920929
# Sentence 903 has a sentiment score of 0.20000000298023224
# Sentence 904 has a sentiment score of -0.10000000149011612
# Sentence 905 has a sentiment score of 0.20000000298023224
# Sentence 906 has a sentiment score of 0.30000001192092896
# Sentence 907 has a sentiment score of 0.20000000298023224
# Sentence 908 has a sentiment score of 0.4000000059604645
# Sentence 909 has a sentiment score of 0.5
# Sentence 910 has a sentiment score of -0.6000000238418579
# Sentence 911 has a sentiment score of 0.30000001192092896
# Sentence 912 has a sentiment score of -0.5
# Sentence 913 has a sentiment score of 0.10000000149011612
# Sentence 914 has a sentiment score of -0.20000000298023224
# Sentence 915 has a sentiment score of 0.4000000059604645
# Sentence 916 has a sentiment score of 0.20000000298023224
# Sentence 917 has a sentiment score of 0.6000000238418579
# Sentence 918 has a sentiment score of -0.20000000298023224
# Sentence 919 has a sentiment score of 0.0
# Sentence 920 has a sentiment score of 0.4000000059604645
# Sentence 921 has a sentiment score of 0.5
# ...
# Sentence 2539 has a sentiment score of -0.4000000059604645
# Sentence 2540 has a sentiment score of 0.30000001192092896
# Sentence 2541 has a sentiment score of -0.20000000298023224
# Sentence 2542 has a sentiment score of -0.20000000298023224
# Sentence 2543 has a sentiment score of 0.800000011920929
# Sentence 2544 has a sentiment score of 0.20000000298023224
# Sentence 2545 has a sentiment score of -0.10000000149011612
# Sentence 2546 has a sentiment score of -0.699999988079071
# Sentence 2547 has a sentiment score of -0.20000000298023224
# Sentence 2548 has a sentiment score of -0.30000001192092896
# Sentence 2549 has a sentiment score of 0.6000000238418579
# Sentence 2550 has a sentiment score of 0.10000000149011612
# Sentence 2551 has a sentiment score of 0.30000001192092896
# Sentence 2552 has a sentiment score of 0.5
# Sentence 2553 has a sentiment score of 0.6000000238418579
# Sentence 2554 has a sentiment score of 0.0
# Sentence 2555 has a sentiment score of 0.6000000238418579
# Sentence 2556 has a sentiment score of 0.5
# Sentence 2557 has a sentiment score of 0.6000000238418579
# Sentence 2558 has a sentiment score of 0.0
# Sentence 2559 has a sentiment score of -0.30000001192092896
# Sentence 2560 has a sentiment score of 0.0
# Sentence 2561 has a sentiment score of 0.0
# Sentence 2562 has a sentiment score of -0.20000000298023224
# Sentence 2563 has a sentiment score of -0.30000001192092896
# Sentence 2564 has a sentiment score of 0.4000000059604645
# Sentence 2565 has a sentiment score of 0.699999988079071
# Sentence 2566 has a sentiment score of 0.0
# Sentence 2567 has a sentiment score of 0.30000001192092896
# Sentence 2568 has a sentiment score of 0.0
# Sentence 2569 has a sentiment score of 0.0
# Sentence 2570 has a sentiment score of 0.8999999761581421
# Sentence 2571 has a sentiment score of 0.10000000149011612
# Sentence 2572 has a sentiment score of -0.20000000298023224
# Sentence 2573 has a sentiment score of 0.20000000298023224
# Sentence 2574 has a sentiment score of 0.0
# Sentence 2575 has a sentiment score of 0.0
# Sentence 2576 has a sentiment score of 0.0
# Sentence 2577 has a sentiment score of -0.10000000149011612
# Sentence 2578 has a sentiment score of 0.0
# Sentence 2579 has a sentiment score of -0.5
# Sentence 2580 has a sentiment score of 0.0
# Sentence 2581 has a sentiment score of -0.10000000149011612
# Sentence 2582 has a sentiment score of -0.30000001192092896
# Sentence 2583 has a sentiment score of 0.0
# Sentence 2584 has a sentiment score of -0.30000001192092896
# Sentence 2585 has a sentiment score of 0.0
# Sentence 2586 has a sentiment score of 0.4000000059604645
# Sentence 2587 has a sentiment score of 0.4000000059604645
# Sentence 2588 has a sentiment score of 0.4000000059604645
# Sentence 2589 has a sentiment score of 0.0
# Sentence 2590 has a sentiment score of -0.10000000149011612
# Sentence 2591 has a sentiment score of 0.5
# Sentence 2592 has a sentiment score of 0.10000000149011612
# Sentence 2593 has a sentiment score of 0.800000011920929
# Sentence 2594 has a sentiment score of 0.0
# Sentence 2595 has a sentiment score of 0.0
# Sentence 2596 has a sentiment score of -0.4000000059604645
# Sentence 2597 has a sentiment score of 0.0
# Sentence 2598 has a sentiment score of -0.20000000298023224
# Sentence 2599 has a sentiment score of 0.10000000149011612
# Sentence 2600 has a sentiment score of 0.0
# Sentence 2601 has a sentiment score of 0.0
# Sentence 2602 has a sentiment score of -0.20000000298023224
# Sentence 2603 has a sentiment score of 0.30000001192092896
# Sentence 2604 has a sentiment score of 0.20000000298023224
# Sentence 2605 has a sentiment score of 0.0
# Sentence 2606 has a sentiment score of -0.10000000149011612
# Sentence 2607 has a sentiment score of 0.0
# Sentence 2608 has a sentiment score of 0.0
# Sentence 2609 has a sentiment score of 0.0
# Sentence 2610 has a sentiment score of -0.5
# Sentence 2611 has a sentiment score of 0.0
# Sentence 2612 has a sentiment score of 0.0
# Sentence 2613 has a sentiment score of 0.0
# Sentence 2614 has a sentiment score of 0.699999988079071
# Sentence 2615 has a sentiment score of 0.6000000238418579
# Sentence 2616 has a sentiment score of 0.800000011920929
# Sentence 2617 has a sentiment score of 0.10000000149011612
# Sentence 2618 has a sentiment score of -0.30000001192092896
# Sentence 2619 has a sentiment score of 0.0
# Sentence 2620 has a sentiment score of -0.30000001192092896
# Sentence 2621 has a sentiment score of 0.4000000059604645
# Sentence 2622 has a sentiment score of 0.0
# Sentence 2623 has a sentiment score of 0.699999988079071
# Sentence 2624 has a sentiment score of -0.20000000298023224
# Sentence 2625 has a sentiment score of 0.0
# Sentence 2626 has a sentiment score of 0.0
# Sentence 2627 has a sentiment score of 0.0
# Sentence 2628 has a sentiment score of 0.20000000298023224
# Sentence 2629 has a sentiment score of 0.10000000149011612
# Sentence 2630 has a sentiment score of 0.20000000298023224
# Sentence 2631 has a sentiment score of 0.20000000298023224
# Sentence 2632 has a sentiment score of -0.6000000238418579
# Sentence 2633 has a sentiment score of 0.0
# Sentence 2634 has a sentiment score of -0.10000000149011612
# Sentence 2635 has a sentiment score of 0.800000011920929
# Sentence 2636 has a sentiment score of 0.0
# Sentence 2637 has a sentiment score of 0.0
# Sentence 2638 has a sentiment score of 0.8999999761581421
# Sentence 2639 has a sentiment score of 0.30000001192092896
# Sentence 2640 has a sentiment score of 0.4000000059604645
# Sentence 2641 has a sentiment score of 0.0
# Sentence 2642 has a sentiment score of 0.800000011920929
# Sentence 2643 has a sentiment score of 0.0
# Sentence 2644 has a sentiment score of 0.0
# Sentence 2645 has a sentiment score of 0.0
# Sentence 2646 has a sentiment score of 0.20000000298023224
# Sentence 2647 has a sentiment score of 0.800000011920929
# Sentence 2648 has a sentiment score of 0.0
# Sentence 2649 has a sentiment score of 0.0
# Sentence 2650 has a sentiment score of 0.10000000149011612
# Sentence 2651 has a sentiment score of 0.10000000149011612
# Sentence 2652 has a sentiment score of 0.4000000059604645
# Sentence 2653 has a sentiment score of 0.800000011920929
# Sentence 2654 has a sentiment score of 0.6000000238418579
# Sentence 2655 has a sentiment score of 0.10000000149011612
# Sentence 2656 has a sentiment score of 0.10000000149011612
# Sentence 2657 has a sentiment score of 0.4000000059604645
# Sentence 2658 has a sentiment score of 0.5
# Sentence 2659 has a sentiment score of 0.0
# Sentence 2660 has a sentiment score of 0.10000000149011612
# Sentence 2661 has a sentiment score of -0.10000000149011612
# Sentence 2662 has a sentiment score of 0.20000000298023224
# Sentence 2663 has a sentiment score of 0.699999988079071
# Sentence 2664 has a sentiment score of 0.699999988079071
# Sentence 2665 has a sentiment score of -0.10000000149011612
# Sentence 2666 has a sentiment score of 0.10000000149011612
# Sentence 2667 has a sentiment score of 0.10000000149011612
# Sentence 2668 has a sentiment score of 0.6000000238418579
# Sentence 2669 has a sentiment score of 0.0
# Sentence 2670 has a sentiment score of 0.4000000059604645
# Sentence 2671 has a sentiment score of 0.4000000059604645
# Sentence 2672 has a sentiment score of -0.4000000059604645
# Sentence 2673 has a sentiment score of -0.30000001192092896
# Sentence 2674 has a sentiment score of 0.0
# Sentence 2675 has a sentiment score of 0.20000000298023224
# Sentence 2676 has a sentiment score of 0.10000000149011612
# Sentence 2677 has a sentiment score of 0.30000001192092896
# Sentence 2678 has a sentiment score of 0.699999988079071
# Sentence 2679 has a sentiment score of 0.10000000149011612
# Sentence 2680 has a sentiment score of 0.0
# Sentence 2681 has a sentiment score of 0.0
# Sentence 2682 has a sentiment score of 0.4000000059604645
# Sentence 2683 has a sentiment score of 0.10000000149011612
# Sentence 2684 has a sentiment score of 0.0
# Sentence 2685 has a sentiment score of 0.6000000238418579
# Sentence 2686 has a sentiment score of -0.4000000059604645
# Sentence 2687 has a sentiment score of -0.4000000059604645
# Sentence 2688 has a sentiment score of 0.0
# Sentence 2689 has a sentiment score of -0.6000000238418579
# Sentence 2690 has a sentiment score of 0.10000000149011612
# Sentence 2691 has a sentiment score of 0.6000000238418579
# Sentence 2692 has a sentiment score of 0.4000000059604645
# Sentence 2693 has a sentiment score of 0.800000011920929
# Sentence 2694 has a sentiment score of 0.800000011920929
# Sentence 2695 has a sentiment score of 0.20000000298023224
# Sentence 2696 has a sentiment score of 0.800000011920929
# Sentence 2697 has a sentiment score of 0.8999999761581421
# Sentence 2698 has a sentiment score of 0.800000011920929
# Sentence 2699 has a sentiment score of 0.699999988079071
# Sentence 2700 has a sentiment score of 0.5
# Sentence 2701 has a sentiment score of 0.5
# Sentence 2702 has a sentiment score of -0.800000011920929
# Sentence 2703 has a sentiment score of -0.20000000298023224
# Sentence 2704 has a sentiment score of 0.800000011920929
# Sentence 2705 has a sentiment score of 0.5
# Sentence 2706 has a sentiment score of 0.6000000238418579
# Sentence 2707 has a sentiment score of 0.0
# Sentence 2708 has a sentiment score of 0.0
# Sentence 2709 has a sentiment score of 0.6000000238418579
# Sentence 2710 has a sentiment score of 0.8999999761581421
# Sentence 2711 has a sentiment score of 0.8999999761581421
# Sentence 2712 has a sentiment score of 0.0
# Sentence 2713 has a sentiment score of 0.800000011920929
# Sentence 2714 has a sentiment score of 0.20000000298023224
# Sentence 2715 has a sentiment score of 0.0
# Sentence 2716 has a sentiment score of 0.0
# Sentence 2717 has a sentiment score of -0.10000000149011612
# Sentence 2718 has a sentiment score of -0.6000000238418579
# Sentence 2719 has a sentiment score of -0.800000011920929
# Sentence 2720 has a sentiment score of 0.0
# Sentence 2721 has a sentiment score of 0.4000000059604645
# Sentence 2722 has a sentiment score of 0.8999999761581421
# Sentence 2723 has a sentiment score of 0.699999988079071
# Sentence 2724 has a sentiment score of 0.0
# Sentence 2725 has a sentiment score of 0.800000011920929
# Sentence 2726 has a sentiment score of 0.0
# Sentence 2727 has a sentiment score of -0.30000001192092896
# Sentence 2728 has a sentiment score of 0.30000001192092896
# Sentence 2729 has a sentiment score of 0.4000000059604645
# Sentence 2730 has a sentiment score of 0.699999988079071
# Sentence 2731 has a sentiment score of 0.10000000149011612
# Sentence 2732 has a sentiment score of 0.0
# Sentence 2733 has a sentiment score of 0.20000000298023224
# Sentence 2734 has a sentiment score of 0.0
# Sentence 2735 has a sentiment score of 0.0
# Sentence 2736 has a sentiment score of 0.4000000059604645
# Sentence 2737 has a sentiment score of -0.4000000059604645
# Sentence 2738 has a sentiment score of 0.0
# Sentence 2739 has a sentiment score of -0.10000000149011612
# Sentence 2740 has a sentiment score of 0.0
# Sentence 2741 has a sentiment score of 0.10000000149011612
# Sentence 2742 has a sentiment score of -0.30000001192092896
# Sentence 2743 has a sentiment score of -0.10000000149011612
# Sentence 2744 has a sentiment score of -0.10000000149011612
# Sentence 2745 has a sentiment score of 0.6000000238418579
# Sentence 2746 has a sentiment score of 0.0
# Sentence 2747 has a sentiment score of 0.10000000149011612
# Sentence 2748 has a sentiment score of 0.0
# Sentence 2749 has a sentiment score of 0.0
# Sentence 2750 has a sentiment score of -0.30000001192092896
# Sentence 2751 has a sentiment score of 0.0
# Sentence 2752 has a sentiment score of 0.30000001192092896
# Sentence 2753 has a sentiment score of 0.0
# Sentence 2754 has a sentiment score of 0.0
# Sentence 2755 has a sentiment score of 0.0
# Sentence 2756 has a sentiment score of 0.0
# Sentence 2757 has a sentiment score of 0.0
# Sentence 2758 has a sentiment score of 0.0
# Sentence 2759 has a sentiment score of 0.0
# Sentence 2760 has a sentiment score of 0.0
# Sentence 2761 has a sentiment score of 0.20000000298023224
# Sentence 2762 has a sentiment score of 0.30000001192092896
# Sentence 2763 has a sentiment score of -0.20000000298023224
# Sentence 2764 has a sentiment score of 0.0
# Sentence 2765 has a sentiment score of 0.0
# Sentence 2766 has a sentiment score of 0.4000000059604645
# Sentence 2767 has a sentiment score of 0.0
# Sentence 2768 has a sentiment score of 0.30000001192092896
# Sentence 2769 has a sentiment score of 0.10000000149011612
# Sentence 2770 has a sentiment score of 0.0
# Sentence 2771 has a sentiment score of -0.10000000149011612
# Sentence 2772 has a sentiment score of -0.30000001192092896
# Sentence 2773 has a sentiment score of -0.4000000059604645
# Sentence 2774 has a sentiment score of 0.0
# Sentence 2775 has a sentiment score of 0.800000011920929
# Sentence 2776 has a sentiment score of 0.0
# Sentence 2777 has a sentiment score of 0.10000000149011612
# Sentence 2778 has a sentiment score of -0.10000000149011612
# Sentence 2779 has a sentiment score of 0.8999999761581421
# Sentence 2780 has a sentiment score of 0.0
# Sentence 2781 has a sentiment score of 0.5
# Sentence 2782 has a sentiment score of 0.0
# Sentence 2783 has a sentiment score of 0.10000000149011612
# Sentence 2784 has a sentiment score of -0.30000001192092896
# Sentence 2785 has a sentiment score of 0.0
# Sentence 2786 has a sentiment score of -0.6000000238418579
# Sentence 2787 has a sentiment score of 0.10000000149011612
# Sentence 2788 has a sentiment score of 0.4000000059604645
# Sentence 2789 has a sentiment score of -0.5
# Sentence 2790 has a sentiment score of 0.20000000298023224
# Sentence 2791 has a sentiment score of -0.4000000059604645
# Sentence 2792 has a sentiment score of 0.0
# Sentence 2793 has a sentiment score of 0.0
# Sentence 2794 has a sentiment score of -0.5
# Sentence 2795 has a sentiment score of 0.0
# Sentence 2796 has a sentiment score of 0.8999999761581421
# Sentence 2797 has a sentiment score of 0.800000011920929
# Sentence 2798 has a sentiment score of 0.0
# Sentence 2799 has a sentiment score of 0.4000000059604645
# Sentence 2800 has a sentiment score of 0.699999988079071
# Sentence 2801 has a sentiment score of 0.30000001192092896
# Sentence 2802 has a sentiment score of 0.20000000298023224
# Sentence 2803 has a sentiment score of 0.0
# Sentence 2804 has a sentiment score of 0.0
# Sentence 2805 has a sentiment score of 0.0
# Sentence 2806 has a sentiment score of 0.0
# Sentence 2807 has a sentiment score of 0.30000001192092896
# Sentence 2808 has a sentiment score of -0.30000001192092896
# Sentence 2809 has a sentiment score of 0.10000000149011612
# Sentence 2810 has a sentiment score of 0.0
# Sentence 2811 has a sentiment score of 0.4000000059604645
# Sentence 2812 has a sentiment score of 0.4000000059604645
# Sentence 2813 has a sentiment score of 0.6000000238418579
# Sentence 2814 has a sentiment score of 0.699999988079071
# Sentence 2815 has a sentiment score of 0.800000011920929
# Sentence 2816 has a sentiment score of -0.10000000149011612
# Sentence 2817 has a sentiment score of 0.4000000059604645
# Sentence 2818 has a sentiment score of 0.699999988079071
# Sentence 2819 has a sentiment score of 0.800000011920929
# Sentence 2820 has a sentiment score of 0.800000011920929
# Sentence 2821 has a sentiment score of 0.10000000149011612
# Sentence 2822 has a sentiment score of 0.8999999761581421
# Sentence 2823 has a sentiment score of 0.20000000298023224
# Sentence 2824 has a sentiment score of 0.699999988079071
# Sentence 2825 has a sentiment score of 0.10000000149011612
# Sentence 2826 has a sentiment score of 0.0
# Sentence 2827 has a sentiment score of -0.4000000059604645
# Sentence 2828 has a sentiment score of 0.0
# Sentence 2829 has a sentiment score of 0.0
# Sentence 2830 has a sentiment score of 0.10000000149011612
# Sentence 2831 has a sentiment score of 0.10000000149011612
# Sentence 2832 has a sentiment score of 0.20000000298023224
# Sentence 2833 has a sentiment score of 0.0
# Sentence 2834 has a sentiment score of 0.0
# Sentence 2835 has a sentiment score of 0.10000000149011612
# Sentence 2836 has a sentiment score of 0.10000000149011612
# Sentence 2837 has a sentiment score of 0.4000000059604645
# Sentence 2838 has a sentiment score of 0.10000000149011612
# Overall Sentiment: score of 0.10000000149011612 with magnitude of 945.4000244140625
